# %% [markdown]
# <a href="https://colab.research.google.com/github/YunusovYF/neural_networks/blob/main/Object_Detection_(YOLOv3)_Ultra_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание Ultra pro
#
# Возьмите любую базу изображений и обучите на ней модель YOLOv3 или RetinaNet. Проверьте результаты.

# %% [markdown]
# *Теоретический материал:* https://youtu.be/KsCWLtIQK9k

# %% [markdown]
# # Подключение библиотек и Google диска
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=193

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ZeroPadding2D, Add, UpSampling2D, Concatenate, Lambda, LeakyReLU # Стандартные слои Keras
from tensorflow.keras.regularizers import l2 # Регуляризатор l2
from tensorflow.keras.optimizers import Adam # Оптимизатор Adam
from tensorflow.keras.models import Model # Абстрактный класс Model
from PIL import Image, ImageDraw, ImageFont # Модули работы с изображениями
from matplotlib.colors import rgb_to_hsv, hsv_to_rgb # Модули конвертации между RGB и HSV
from google.colab import files # Модуль работы с файловой системой google

import tensorflow.keras.backend as K # бэкенд Keras
import math # Импортируем модуль math
import pandas as pd # Пандас для работы с csv
import tensorflow as tf # TensorFlow
import numpy as np # numpy массивы
import matplotlib.pyplot as plt # графики
import os # модуль работы с файловой системой
import time # модуль работы со временем

# %%
from google.colab import drive # подключаем гугл драйв диск для загрузки файлов
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Глобальные параметры
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=251

# %%
path = '/content/drive/MyDrive/Baza/Object_detection/Nail/' # Путь к директории на диске, где находятся изображения
name_classes = ['Самолеты'] # Названия классов
num_classes = len(name_classes) # Количество классов
input_shape = (416, 416) # Размерность входного изображения для модели YOLO

# Массив используемых анкоров (в пикселях). Используетя по 3 анкора на каждый из 3 уровней сеток
# данные значения коррелируются с размерностью входного изображения input_shape
anchors = np.array([[10, 13], [16, 30], [33, 23], [30, 61], [62, 45], [59, 119], [116, 90], [156, 198], [373, 326]]) 
num_anchors = len(anchors) # Сохраняем количество анкоров

# %% [markdown]
# # Создание модели

# %% [markdown]
# ## Функции
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=400

# %%
'''
    Функция создания полной модели
        Входные параметры:       
          input_shape - размерность входного изображения для модели YOLO
          num_anchors - общее количество анкоров   
          use_weights - использовать ли предобученные веса         
          weights_path - путь к сохраненным весам модели  
'''
def create_model(
        input_shape,
        num_anchors,
        use_weights = False, 
        weights_path = 'yolo.h5'        
        ):
    w, h = input_shape # Получаем ширину и высоту входного изображения
    inputs = Input(shape = (w, h, 3)) # Создаем входной слой модели, добавляя размерность для глубины цвета
    
    # Создаем три входных слоя y_true с размерностями ((None, 13, 13, 3, 6), (None, 26, 26, 3, 6) и (None, 52, 52, 3, 6))
    # 2 и 3 параметры (13, 13) указывают размерность сетки, на которую условно будет разбито исходное изображение
    # каждый уровень сетки отвечает за обнаружение объектов различных размеров (13 - крупных, 26 - средних, 52 - мелких)
    # 4 параметр - количество анкоров на каждый уровень сетки
    # 5 параметр - 4 параметра описывающие параметры анкора (координаты центра, ширина и высота) + вероятность обнаружения объекта + OHE номер класса
    y_true = [Input (shape = (w // 32, h // 32, num_anchors // 3, num_classes + 5))] # Уровень сетки 13х13 (416/32)
    y_true.append (Input (shape = (w // 16, h // 16, num_anchors // 3, num_classes + 5))) # Уровень сетки 26х26 (416/26)
    y_true.append (Input (shape = (w // 8, h // 8, num_anchors // 3, num_classes + 5))) # Уровень сетки 52х52 (416/8)
    
    model_yolo = create_YOLOv3(inputs, num_anchors // 3) # Создаем модель YOLOv3
    print ('Создана модель YOLOv3. Количество классов: {}.'.format(num_classes)) # Выводим сообщение о создании модели
    
    # Если установлен флаг загрузки весов
    if use_weights:
        model_yolo.load_weights(weights_path, by_name = False, skip_mismatch = False) # Загружаем предобученные веса
        print ('Загружены веса из файла {}.'.format(weights_path)) # Выводим сообщение о загруженных весах
        
    # Создаем выходной слой Lambda (выходом которого будет значение ошибки модели)
    # На вход слоя подается:
    #   - model_yolo.output (выход модели model_yolo (то есть то, что посчитала сеть))
    #   - y_true (оригинальные данные из обучающей выборки)
    outputs = Lambda(yolo_loss, output_shape = (1,), name = 'yolo_loss', arguments = {'num_anchors' : num_anchors}) ([*model_yolo.output, *y_true])
    
    return Model([inputs, *y_true], outputs) # Возвращаем модель

# %%
'''
Функция создания модели YOLOv3
    Входные параметры:
          inputs - Входной слой модели
          num_sub_anchors - количество анкоров в каждом уровне сеток
'''
def create_YOLOv3(
        inputs,
        num_sub_anchors
        ):
    #--------------------
    # Базовая часть модели YOLOv3
    #--------------------
    
    # Состоит из Conv2D-слоев и Residual-блоков. Residual-блок - это блок использующий информацию из предыдущих слоев.
    # С помощью слоя Add (Суммируется текущий слой и один из предыдущих), что позволяет избежать проблему потери информации
    # Количество resedual блоков и архитектура сети взята из документации YOLOv3
    x = ConvBL (inputs, 32, (3, 3)) # Добавляем каскад из трех слоев (Conv2D, BatchNormalization и Leaky)
    x = resblock (x, 64, 1) # Добавляем 1 resedual-блок с 64 нейронами
    x = resblock (x, 128, 2) # Добавляем 2 resedual-блока с 128 нейронами
    x = resblock (x, 256, 8) # Добавляем 8 resedual-блоков с 256 нейронами
    x = resblock (x, 512, 8) # Добавляем 8 resedual-блоков с 512 нейронами
    x = resblock (x, 1024, 4) # Добавляем 4 resedual-блоков с 1024 нейронами
    base_model = Model(inputs, x) # Создаем базовую часть модели YOLOv3
    
    #--------------------
    # Detection часть модели YOLOv3
    #--------------------
    
    # Выделяем три выхода сети, соответсвующих различным уровням сетки
    
    
    # 13 x 13 (обнаружение больших объектов)
    x = ConvBL(base_model.output, 512, (1, 1))    
    x = ConvBL(x, 1024, (3, 3))
    x = ConvBL(x, 512, (1, 1))
    x = ConvBL(x, 1024, (3, 3))
    x = ConvBL(x, 512, (1, 1))
    
    # Выделяем первый выход модели, соответствующий размерности 13 х 13
    y1 = ConvBL(x, 1024, (3,3))
    y1 = Conv2D(num_sub_anchors * (num_classes + 5), (1, 1), padding = 'same', kernel_regularizer = l2(5e-4)) (y1)
    
    
    # 26x26 (обнаружение средних объектов)
    
    # Размерность текущего выхода сети равна 13 х 13. Необходимо увеличить ее до 26 x 26 и
    # объеденить со 152-ым слоем (размерностью 26 x 26)
    x = ConvBL(x, 256, ( 1, 1)) 
    x = UpSampling2D(2) (x) # Увеличиваем размерность до 26 на 26, использую UpSampling
    x = Concatenate()([x,base_model.layers[152].output])
    
    # Добавляем 5 блоков ConvBL
    x = ConvBL(x, 256, (1, 1))  
    x = ConvBL(x, 512, (3, 3))
    x = ConvBL(x, 256, (1, 1))
    x = ConvBL(x, 512, (3, 3))
    x = ConvBL(x, 256, (1, 1))
    
    # Выделяем второй выход модели, соответствующий размерности 26 х 26
    y2 = ConvBL(x, 512, (3, 3))
    y2 = Conv2D(num_sub_anchors * (num_classes + 5), (1, 1), padding = 'same', kernel_regularizer = l2(5e-4)) (y2)
    
    # 52 x 52 (обнаружение маленьких объектов)
    
    # Размерность текущего выхода сети равна 26 х 26. Необходимо увеличить ее до 52 x 52 и
    # объеденить со 92-ым слоем (размерностью 52 x 52)
    x = ConvBL(x, 128, ( 1, 1)) 
    x = UpSampling2D(2) (x)  # Увеличиваем размерность до 52 на 52, использую UpSampling
    x = Concatenate()([x,base_model.layers[92].output])
    
    # Добавляем 5 блоков ConvBL
    x = ConvBL(x, 128, (1, 1))  
    x = ConvBL(x, 256, (3, 3))
    x = ConvBL(x, 128, (1, 1))
    x = ConvBL(x, 256, (3, 3))
    x = ConvBL(x, 128, (1, 1))
    
    # Выделяем третий выход модели, соответствующий размерности 52 х 52
    y3 = ConvBL(x, 256, (3, 3))
    y3 = Conv2D(num_sub_anchors * (num_classes + 5), (1, 1), padding = 'same', kernel_regularizer = l2(5e-4)) (y3)
    
    return Model(inputs, [y1, y2, y3]) # Возвращаем модель

# %%
''' Функция создания Residual блока.
    Входные параметры:
          inputs - Стартовый слой, к которому добавляется Res-блок
          num_filters - количество нейронов
          num_blocks  - количество блоков 
 '''
def resblock(
        inputs,
        num_filters,
        num_blocks
        ):
    x = ZeroPadding2D(((1, 0), (1, 0)))(inputs) # Увеличиваем размерность на один шаг влево и вверх
    x = ConvBL(x, num_filters, (3, 3), strides=(2, 2)) # Добавляем блок ConvBL
    for i in range(num_blocks): # Пробегаем в цикле num_blocks-раз (суммируя слои с помощью Add())
        y = ConvBL(x, num_filters // 2, (1, 1))
        y = ConvBL(y, num_filters, (3, 3))
        x = Add() ([x, y])
    return x # Возвращаем слой

# %%
''' Функция создания блока Conv2D, BatchNormalization, LeakyRelu
    Входные параметры:
          inputs - Стартовый слой, к которому добавляется Res-блок
          args - массив неименованных параметров
          kwargs  - массив именованных параметров
 '''
def ConvBL(
        inputs,
        *args,
        **kwargs
        ): 
    new_kwargs = {'use_bias': False} # создаем новый массив именованных параметров, добавляя параметр use_bias
    new_kwargs['kernel_regularizer'] = l2(5e-4) # добавляем параметр kernel_regularizerpadding
    new_kwargs['padding'] = 'valid' if kwargs.get('strides') == (2, 2) else 'same' # добавляем параметр  padding
    new_kwargs.update(kwargs) # Добавляем уже имеющиеся в kwargs gfhfvtnhs
    x = Conv2D(*args, **new_kwargs) (inputs) # Добавляем Conv2D слой
    x = BatchNormalization() (x) # Добавляем слой BatchNormalization
    x = LeakyReLU(alpha=0.1) (x) # Добавляем слой LeakyRelu
    return x

# %%
'''
Функция подсчета ошибки.
    Входные параметры:
        inputs - Входные данные
        num_anchors - общее количество анкоров                    
'''
def yolo_loss(
      inputs,
      num_anchors
      ):
    ignore_thresh = .5 # Порог вероятности обнаружения объекта
    num_layers = num_anchors // 3 # Подсчитываем количество анкоров на каждом уровне сетки
    y_pred = inputs[:num_layers] # Из входных данных выцепляем посчитанные моделью значения
    y_true = inputs[num_layers:] # Из входных данных выцепляем эталонные значения
    anchor_mask = [[6, 7, 8], [3, 4, 5], [0, 1, 2]] # Задаем маску анкоров для каждого уровня сеток
    # ([[10, 13], [16, 30], [33, 23], [30, 61], [62, 45], [59, 119], [116, 90], [156, 198], [373, 326]])
   
    
    # Получаем размерность входного изображения ( (13 х 13) * 32 = (416 х 416)) и приводим к типу элемента y_true[0]
    input_shape = K.cast(K.shape(y_pred[0])[1:3] * 32, K.dtype(y_true[0])) 
    
    # Получаем двумерный массив, соответствующий размерностям сеток ((13, 13), (26, 26), (52, 52))
    grid_shapes = [K.cast(K.shape(y_pred[l])[1:3], K.dtype(y_true[0])) for l in range(num_layers)]
    
    loss = 0 # Значение ошибки
    
    # Считываем количество элементов
    m = K.shape(y_pred[0])[0] # Размер пакета
    batch_size = K.cast(m, K.dtype(y_pred[0])) # Преобразуем к типу y_pred[0]
    
    for l in range(num_layers): # Пробегаем по всем трем уровням сеток
        # Получаем маску для сетки l-го уровня по вероятности определения объекта (5-ый параметр в списке общих параметров). 
        # В массиве object_mask будут значения, которые соответствуют только вероятности обнаружения объекта
        object_mask = y_true[l][..., 4:5] # Вернется набор данных вида: ([0][0][0][0]...[1]...[0])
        
        # Получаем аналогичную выборку для сетки l-го уровня с OHE (где записана позиция нашего класса)
        # В массиве true_class будут значения, которые соответсвуют только OHE представлению класса ядля данного уровня анкоров
        true_class = y_true[l][..., 5:] # Вернется набор данных вида: ([0][0][0][0]...[1]...[0])
        
        num_sub_anchors = len(anchors[anchor_mask[l]]) # Получаем количество анкоров для отдельного уровян сетки (3)
        
        # Решейпим анкоры отдельного уровня сетки и записываем в переменную anchors_tensor
        anchors_tensor = K.reshape(K.constant(anchors[anchor_mask[l]]), [1, 1, 1, num_sub_anchors, 2])
        
        # Создаем двумерный массив grid со значениями [[[0, 0] , [0, 1] , [0, 2] , ... , [0, k]], 
        #                                             [[1, 0] , [1, 1] , [1, 2] , ... , [1 ,k]],
        #                                             ...
        #                                             [[k, 0] , [k, 1] , [k, 2] , ... , [k, k]]]
        # где k - размерность сетки. Массив хранит индексы ячеек сетки
        grid_shape = K.shape(y_pred[l])[1:3] # Получаем ширину и высоту сетки
        grid_y = K.tile(K.reshape(K.arange(0, stop=grid_shape[0]), [-1, 1, 1, 1]),[1, grid_shape[1], 1, 1]) # Создаем вертикальную линию
        grid_x = K.tile(K.reshape(K.arange(0, stop=grid_shape[1]), [1, -1, 1, 1]),[grid_shape[0], 1, 1, 1]) # Создаем горизонтальную линию
        grid = K.concatenate([grid_x, grid_y]) # Объединяем 
        grid = K.cast(grid, K.dtype(y_pred[l])) # Приводим к типу y_pred[l]
        
        # Решейпим y_pred[l]
        feats = K.reshape(y_pred[l], [-1, grid_shape[0], grid_shape[1], num_sub_anchors, num_classes + 5]) 
        
        # Считаем ошибку в определении координат центра объекта
        # Получаем координаты центра объекта из спредиктенного значения
        pred_xy = (K.sigmoid(feats[..., :2]) + grid) / K.cast(grid_shape[::-1], K.dtype(feats)) 
        # Производим обратные вычесления для оригинальных значений из y_true для координат центра объекта
        true_xy = y_true[l][..., :2] * grid_shapes[l][::-1] - grid  # Реальные координаты центра bounding_box
        box_loss_scale = 2 - y_true[l][...,2:3] * y_true[l][...,3:4] # чем больше бокс, тем меньше ошибка
        # binary_crossentropy для истинного значения и спредиктенного (obect_mask для подсчета только требуемого значения)
        xy_loss = object_mask * box_loss_scale * K.binary_crossentropy(true_xy, feats[...,0:2], from_logits=True)

        # Считаем ошибку в определении координат ширины и высоты
        # Получаем значения ширины и высоты изображения из спредиктенного значения   
        pred_wh = K.exp(feats[..., 2:4]) * anchors_tensor / K.cast(input_shape[::-1], K.dtype(feats)) 
        # Производим обратные вычесления для оригинальных значений из y_true для ширины и высоты объекта
        true_wh = K.log(y_true[l][..., 2:4] / anchors[anchor_mask[l]] * input_shape[::-1]) 
        # Оставляем значение высоты и ширины только у тех элементов, где object_mask = 1
        true_wh = K.switch(object_mask, true_wh, K.zeros_like(true_wh)) 
        # Считаем значение ошибки в определении высоты и ширины
        wh_loss = object_mask * box_loss_scale * 0.5 * K.square(true_wh-feats[...,2:4])
        
        # Объединяем значения в один  массив
        pred_box = K.concatenate([pred_xy, pred_wh]) 
        
        # Считаем ошибку в определении обнаружения какого-либо класса
        # Для этого вначале надо отсечь все найденные объекты, вероятность которых меньше установленного значения ignore_thresh
        
        # Определяем массив, который будет хранить данные о неподходящих значениях
        ignore_mask = tf.TensorArray(K.dtype(y_true[0]), size=1, dynamic_size=True) 
        object_mask_bool = K.cast(object_mask, 'bool') # Приводим тип object_mask к типу 'bool'
        
        # Функция, определяющая данные, которые требуется игнорировать
        # Пробегаем по всем элементам пакета (b<m)
        # Получаем параметры реального bounding_box для текущей ячейки
        # Считаем IoU реального и спредиктенного
        # В зависимости от best_iou < ignore_thresh помечаем его как верно распознанный или неверено
        def loop_body(
                b,
                ignore_mask
                ):
            # в true_box запишутся первыые 4 параметра (центр, высота и ширина объекта) того элемента, значение которого в object_mask_bool равно True
            true_box = tf.boolean_mask(y_true[l][b,...,0:4], object_mask_bool[b,...,0]) 
            # Подсчитываем iou для спредиктенной ограничивающей рамки (pred_box) и оригинальной (true_box)
            iou = calc_iou(pred_box[b], true_box) 
            # Находим лучшую ограничивающую рамку
            best_iou = K.max(iou, axis=-1) 
            # Записываем в ignore_mask true или false в зависимости от (best_iou < ignore_thresh)
            ignore_mask = ignore_mask.write(b, K.cast(best_iou < ignore_thresh, K.dtype(true_box))) 
            return b+1, ignore_mask # Увеличиваем счетчик на еденицу и возвращаем ignore_mask
        
        # Пробегаем в цикле по всем элементам в пределах значения m (m = batch size)
        _, ignore_mask = tf.while_loop(lambda b,*args: b<m, loop_body, [0, ignore_mask]) 
        ignore_mask = ignore_mask.stack() # Приводим ignore_mask к тензору
        ignore_mask = K.expand_dims(ignore_mask, -1) # Добавляем еще одну размерность в конце ignore_mask
                 
        # Считаем значение ошибки
        # 1 компонентя - для значений, которые были верно спредиктены
        # 2 компонентя - для значения, которые были неверно спредиктены
        confidence_loss = (
            object_mask * K.binary_crossentropy(object_mask, feats[...,4:5], from_logits=True) +
            (1-object_mask) * K.binary_crossentropy(object_mask, feats[...,4:5], from_logits=True) * ignore_mask
            )
        
        # Считаем ошибку в определении класса объекта
        class_loss = object_mask * K.binary_crossentropy(true_class, feats[...,5:], from_logits=True)
    
        # Считаем суммарную ошибку
        xy_loss = K.sum(xy_loss) / batch_size
        wh_loss = K.sum(wh_loss) / batch_size
        confidence_loss = K.sum(confidence_loss) / batch_size
        class_loss = K.sum(class_loss) / batch_size
        loss += xy_loss + wh_loss + confidence_loss + class_loss
                
    return loss # Возвращаем значение ошибки

# %%
'''
    Функция подсчета IoU
'''
def calc_iou(input1, input2):
    input1 = K.expand_dims(input1, -2) # Добавляем одну размерность
    xy1 = input1[..., :2] # Получаем координаты x,y центра 
    wh1 = input1[..., 2:4] # Получаем значения высоты и ширины
    wh_half1 = wh1 / 2. # Делим значения высоты и ширины пополам
    top_left1 = xy1 - wh_half1 # Получаем значение, соответствующее верхнему левому углу
    right_bottom1 = xy1 + wh_half1 # Получаем значение, соотвествующее правому нижнему углу
    
    input2 = K.expand_dims(input2, 0) # Добавляем одну размерность
    xy2 = input2[..., :2] # Получаем координаты x,y центра 
    wh2 = input2[..., 2:4] # Получаем значения высоты и ширины
    wh_half2 = wh2 / 2. # Делим значения высоты и ширины пополам
    top_left2 = xy2 - wh_half2 # Получаем значение, соответствующее верхнему левому углу
    right_bottom2 = xy2 + wh_half2 # Получаем значение, соотвествующее правому нижнему углу
    
    intersect_mins = K.maximum(top_left1, top_left2) # Берем максимальные координаты из левых верхних углов
    intersect_maxes = K.minimum(right_bottom1, right_bottom2) # Берем Минимальные координаты координаты из правых нижних углов
    intersect_wh = K.maximum(intersect_maxes - intersect_mins, 0.) # Считаем ширину и высоту области пересечения
    intersect_area = intersect_wh[..., 0] * intersect_wh[..., 1] # Считаем площадь области пересечения
    
    area1 = wh1[..., 0] * wh1[..., 1] # Считаем площадь первых элементов
    area2 = wh2[..., 0] * wh2[..., 1] # Считаем площадь вторых элементов
    
    return intersect_area / (area1 + area2 - intersect_area) # Возвращаем IoU

# %% [markdown]
# ## Основной код
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=2920

# %%
# Создаем модель
model_YOLO = create_model(input_shape, num_anchors, use_weights=True, weights_path=path +'weights/YOLOv3__el1000__opt0.00001__ep0_100.h5')
# Out:
# Создана модель YOLOv3. Количество классов: 1.
# Загружены веса из файла /content/drive/MyDrive/Baza/Object_detection/Nail/weights/YOLOv3__el1000__opt0.00001__ep0_100.h5.

# %%
# Выводим входные размерности для модели
model_YOLO.input
# Out:
# [<KerasTensor: shape=(None, 416, 416, 3) dtype=float32 (created by layer 'input_13')>,
#  <KerasTensor: shape=(None, 13, 13, 3, 6) dtype=float32 (created by layer 'input_14')>,
#  <KerasTensor: shape=(None, 26, 26, 3, 6) dtype=float32 (created by layer 'input_15')>,
#  <KerasTensor: shape=(None, 52, 52, 3, 6) dtype=float32 (created by layer 'input_16')>]

# %%
# Выводим выходныую размерность модели
model_YOLO.output
# Out:
# <KerasTensor: shape=() dtype=float32 (created by layer 'yolo_loss')>

# %%
# Выводим информацию о модели
model_YOLO.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 416, 416, 32) 864         input_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 416, 416, 32) 128         conv2d_225[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_216 (LeakyReLU)     (None, 416, 416, 32) 0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 417, 417, 32) 0           leaky_re_lu_216[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 208, 208, 64) 18432       zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 208, 208, 64) 256         conv2d_226[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_217 (LeakyReLU)     (None, 208, 208, 64) 0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 208, 208, 32) 2048        leaky_re_lu_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 208, 208, 32) 128         conv2d_227[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_218 (LeakyReLU)     (None, 208, 208, 32) 0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 208, 208, 64) 18432       leaky_re_lu_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 208, 208, 64) 256         conv2d_228[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_219 (LeakyReLU)     (None, 208, 208, 64) 0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 208, 208, 64) 0           leaky_re_lu_217[0][0]
#                                                                  leaky_re_lu_219[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 209, 209, 64) 0           add_69[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 104, 104, 128 73728       zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 104, 104, 128 512         conv2d_229[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_220 (LeakyReLU)     (None, 104, 104, 128 0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 104, 104, 64) 8192        leaky_re_lu_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 104, 104, 64) 256         conv2d_230[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_221 (LeakyReLU)     (None, 104, 104, 64) 0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 104, 104, 128 73728       leaky_re_lu_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 104, 104, 128 512         conv2d_231[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_222 (LeakyReLU)     (None, 104, 104, 128 0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 104, 104, 128 0           leaky_re_lu_220[0][0]
#                                                                  leaky_re_lu_222[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 104, 104, 64) 8192        add_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 104, 104, 64) 256         conv2d_232[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_223 (LeakyReLU)     (None, 104, 104, 64) 0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 104, 104, 128 73728       leaky_re_lu_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 104, 104, 128 512         conv2d_233[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_224 (LeakyReLU)     (None, 104, 104, 128 0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 104, 104, 128 0           add_70[0][0]
#                                                                  leaky_re_lu_224[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 105, 105, 128 0           add_71[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 52, 52, 256)  294912      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 52, 52, 256)  1024        conv2d_234[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_225 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 52, 52, 128)  32768       leaky_re_lu_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 52, 52, 128)  512         conv2d_235[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_226 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 52, 52, 256)  1024        conv2d_236[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_227 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 52, 52, 256)  0           leaky_re_lu_225[0][0]
#                                                                  leaky_re_lu_227[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 52, 52, 128)  32768       add_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 52, 52, 128)  512         conv2d_237[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_228 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 52, 52, 256)  1024        conv2d_238[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_229 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 52, 52, 256)  0           add_72[0][0]
#                                                                  leaky_re_lu_229[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 52, 52, 128)  32768       add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 52, 52, 128)  512         conv2d_239[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_230 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 52, 52, 256)  1024        conv2d_240[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_231 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 52, 52, 256)  0           add_73[0][0]
#                                                                  leaky_re_lu_231[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 52, 52, 128)  32768       add_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 52, 52, 128)  512         conv2d_241[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_232 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 52, 52, 256)  1024        conv2d_242[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_233 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 52, 52, 256)  0           add_74[0][0]
#                                                                  leaky_re_lu_233[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 52, 52, 128)  32768       add_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 52, 52, 128)  512         conv2d_243[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_234 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 52, 52, 256)  1024        conv2d_244[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_235 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 52, 52, 256)  0           add_75[0][0]
#                                                                  leaky_re_lu_235[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 52, 52, 128)  32768       add_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 52, 52, 128)  512         conv2d_245[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_236 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 52, 52, 256)  1024        conv2d_246[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_237 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 52, 52, 256)  0           add_76[0][0]
#                                                                  leaky_re_lu_237[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 52, 52, 128)  32768       add_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 52, 52, 128)  512         conv2d_247[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_238 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 52, 52, 256)  1024        conv2d_248[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_239 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 52, 52, 256)  0           add_77[0][0]
#                                                                  leaky_re_lu_239[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 52, 52, 128)  32768       add_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 52, 52, 128)  512         conv2d_249[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_240 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 52, 52, 256)  1024        conv2d_250[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_241 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 52, 52, 256)  0           add_78[0][0]
#                                                                  leaky_re_lu_241[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 53, 53, 256)  0           add_79[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 26, 26, 512)  1179648     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 26, 26, 512)  2048        conv2d_251[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_242 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 26, 26, 256)  131072      leaky_re_lu_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 26, 26, 256)  1024        conv2d_252[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_243 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 26, 26, 512)  2048        conv2d_253[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_244 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 26, 26, 512)  0           leaky_re_lu_242[0][0]
#                                                                  leaky_re_lu_244[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 26, 26, 256)  131072      add_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 26, 26, 256)  1024        conv2d_254[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_245 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 26, 26, 512)  2048        conv2d_255[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_246 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 26, 26, 512)  0           add_80[0][0]
#                                                                  leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 26, 26, 256)  131072      add_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 26, 26, 256)  1024        conv2d_256[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_247 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 26, 26, 512)  2048        conv2d_257[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_248 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 26, 26, 512)  0           add_81[0][0]
#                                                                  leaky_re_lu_248[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 26, 26, 256)  131072      add_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 26, 26, 256)  1024        conv2d_258[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_249 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 26, 26, 512)  2048        conv2d_259[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_250 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 26, 26, 512)  0           add_82[0][0]
#                                                                  leaky_re_lu_250[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 26, 26, 256)  131072      add_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 26, 26, 256)  1024        conv2d_260[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_251 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 26, 26, 512)  2048        conv2d_261[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_252 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 26, 26, 512)  0           add_83[0][0]
#                                                                  leaky_re_lu_252[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 26, 26, 256)  131072      add_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 26, 26, 256)  1024        conv2d_262[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_253 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 26, 26, 512)  2048        conv2d_263[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_254 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 26, 26, 512)  0           add_84[0][0]
#                                                                  leaky_re_lu_254[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 26, 26, 256)  131072      add_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 26, 26, 256)  1024        conv2d_264[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_255 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 26, 26, 512)  2048        conv2d_265[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_256 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 26, 26, 512)  0           add_85[0][0]
#                                                                  leaky_re_lu_256[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 26, 26, 256)  131072      add_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 26, 26, 256)  1024        conv2d_266[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_257 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 26, 26, 512)  2048        conv2d_267[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_258 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 26, 26, 512)  0           add_86[0][0]
#                                                                  leaky_re_lu_258[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 27, 27, 512)  0           add_87[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 13, 13, 1024) 4718592     zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 13, 13, 1024) 4096        conv2d_268[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_259 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 13, 13, 512)  524288      leaky_re_lu_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 13, 13, 512)  2048        conv2d_269[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_260 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 13, 13, 1024) 4096        conv2d_270[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_261 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 13, 13, 1024) 0           leaky_re_lu_259[0][0]
#                                                                  leaky_re_lu_261[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 13, 13, 512)  524288      add_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 13, 13, 512)  2048        conv2d_271[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_262 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 13, 13, 1024) 4096        conv2d_272[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_263 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 13, 13, 1024) 0           add_88[0][0]
#                                                                  leaky_re_lu_263[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 13, 13, 512)  524288      add_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 13, 13, 512)  2048        conv2d_273[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_264 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 13, 13, 1024) 4096        conv2d_274[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_265 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 13, 13, 1024) 0           add_89[0][0]
#                                                                  leaky_re_lu_265[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 13, 13, 512)  524288      add_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 13, 13, 512)  2048        conv2d_275[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_266 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 13, 13, 1024) 4096        conv2d_276[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_267 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 13, 13, 1024) 0           add_90[0][0]
#                                                                  leaky_re_lu_267[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 13, 13, 512)  524288      add_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 13, 13, 512)  2048        conv2d_277[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_268 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 13, 13, 1024) 4096        conv2d_278[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_269 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 13, 13, 512)  524288      leaky_re_lu_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 13, 13, 512)  2048        conv2d_279[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_270 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 13, 13, 1024) 4096        conv2d_280[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_271 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 13, 13, 512)  524288      leaky_re_lu_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 13, 13, 512)  2048        conv2d_281[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_272 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 13, 13, 256)  131072      leaky_re_lu_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 13, 13, 256)  1024        conv2d_284[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_274 (LeakyReLU)     (None, 13, 13, 256)  0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 26, 26, 256)  0           leaky_re_lu_274[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 26, 26, 768)  0           up_sampling2d_6[0][0]
#                                                                  add_87[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 26, 26, 256)  196608      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 26, 26, 256)  1024        conv2d_285[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_275 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 26, 26, 512)  2048        conv2d_286[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_276 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 26, 26, 256)  131072      leaky_re_lu_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 26, 26, 256)  1024        conv2d_287[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_277 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 26, 26, 512)  2048        conv2d_288[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_278 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 26, 26, 256)  131072      leaky_re_lu_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 26, 26, 256)  1024        conv2d_289[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_279 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 26, 26, 128)  32768       leaky_re_lu_279[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 26, 26, 128)  512         conv2d_292[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_281 (LeakyReLU)     (None, 26, 26, 128)  0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 52, 52, 128)  0           leaky_re_lu_281[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 52, 52, 384)  0           up_sampling2d_7[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 52, 52, 128)  49152       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 52, 52, 128)  512         conv2d_293[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_282 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_282[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 52, 52, 256)  1024        conv2d_294[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_283 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 52, 52, 128)  32768       leaky_re_lu_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 52, 52, 128)  512         conv2d_295[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_284 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 52, 52, 256)  1024        conv2d_296[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_285 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 52, 52, 128)  32768       leaky_re_lu_285[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 52, 52, 128)  512         conv2d_297[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_286 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_272[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_279[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_286[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 13, 13, 1024) 4096        conv2d_282[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 26, 26, 512)  2048        conv2d_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 52, 52, 256)  1024        conv2d_298[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_273 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_280 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_287 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 13, 13, 18)   18450       leaky_re_lu_273[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 26, 26, 18)   9234        leaky_re_lu_280[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 52, 52, 18)   4626        leaky_re_lu_287[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 13, 13, 3, 6 0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 26, 26, 3, 6 0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 52, 52, 3, 6 0
# __________________________________________________________________________________________________
# yolo_loss (Lambda)              ()                   0           conv2d_283[0][0]
#                                                                  conv2d_291[0][0]
#                                                                  conv2d_299[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# ==================================================================================================
# Total params: 61,576,342
# Trainable params: 61,523,734
# Non-trainable params: 52,608
# __________________________________________________________________________________________________

# %% [markdown]
# # Обучение модели

# %% [markdown]
# ## Демонстрация подготовки данных для обучения
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=2988

# %% [markdown]
# На вход модели подается 2 параметра:
#        1. numpy-массив размерностью (416,416,3), соответствующий исходному изображению
#        2. трехмерный массив y_true, в котором записана информация об анкоре, описывающем наш объект
#              размерность первого элемента массива (13,13,3,6) -  13на13 - размер сетки,
#                                                                   3 - количество анкоров для каждой ячейки сетки,
#                                                                   6 - параметры анкора
#              размерность второго элемента массива (26,26,3,6)
#              размерность третьего элемента массива (52,52,3,6)

# %%
# Открываем файл сегментированной модели
filename = 'nail_1' # Имя файла
image = Image.open(path+'Segment/'+filename+'.jpg') # Загружаем изображение сегментированной модели
img1 = ImageDraw.Draw(image) # Создаем экземпляр изображения
plt.imshow(image) # Рисуем изображение

# %%
# Находим координаты ограничивающего бокса (ищем по красному параметру в массиве RGB)
image_n = np.array(image) # Переводим в numpy
image_red = image_n[:,:,0] # Оставляем только красный цвет
itemindex = np.array(np.where(image_red > 20 )) # Ищем все элементы, в которых значение красного цвета больше 20
# np.where веренет двумерный кортеж, где первый элемент соответсвует найденным строкам, второй - найженным столбцам
minY = min (itemindex[0]) # minY будет соответствовать минимальному значению в первом элементе itemindex
maxY = max (itemindex[0]) # maxY будет соответствовать максимальному значению в первом элементе itemindex
minX = min (itemindex[1]) # minX будет соответствовать минимальному значению во втором элементе itemindex
maxX = max (itemindex[1]) # maxX будет соответствовать максимальному значению во втором элементе itemindex
print ('minX = ',minX, '    minY = ', minY, '    maxX = ', maxX, '    maxY = ',maxY, sep='') # Выводим найденные значения

# Рисуем ограничивающую рамку
for i in range(10):
  img1.rectangle([minX+i,minY+i,maxX-i,maxY-i], outline = 'green')
plt.imshow(image)
# Out:
# minX = 63    minY = 0    maxX = 304    maxY = 409

# %%
# Запишем всю информацию об объекте в словарь
dictionary = {} # Создаем словарь
class_id = 0 # Номер класса. У нас всего один класс
key = filename # Значение ключа соответсвует имени модели
dictionary[key] = 'Nail/'+key+'.jpg'+' '+str(minX)+','+str(minY)+','+str(maxX)+','+str(maxY)+','+str(class_id) # Записываем
      # информацию об изображении: Имя_файла minX,minY,maxX,maxY,class_id
print (dictionary) # Выводим словарь
# Out:
# {'nail_1': 'Nail/nail_1.jpg 63,0,304,409,0'}

# %%
# Загружаем оригинальное изображение
line = dictionary[filename].split() # Сплитим по пробелу значение в словаре: 'Air/airplane_10.jpg 332,360,1661,736,0'
image = Image.open(path+line[0]) # Загружаем файл изображения
iw, ih = image.size # Запоминаем оригинальные размеры изображения
w, h = (416,416) # Устанавливаем ширину и высоту изображения для модели YOLO
box = np.array([np.array(list(map(lambda x: int((float)(x)),box.split(',')))) for box in line[1:]]) # Получаем список параметров для ограничивающих рамом для всех объектов
                                                                                            # на изображении. В нашем случае будет всего одна ограничивающая рамка
plt.imshow(image)   # рисуем изображение        
print ('Размер исходного изображения: ',iw, ih) # Выводим размер исходного изображения
print ('Размерность входных данных для модели:', h, w) # Выводим размеры изображения для входного слоя модели YOLO
print ('Параметры ограничивающей рамки', box) # Выводим параметры ограничивающей рамки
# Out:
# Размер исходного изображения:  384 512
# Размерность входных данных для модели: 416 416
# Параметры ограничивающей рамки [[ 63   0 304 409   0]]

# %%
# Аугментация изображения

# Функция получения случайного числа
def rand(a = 0, b = 1):
  return np.random.rand() * (b - a) + a

# -----
# Параметры для аугментации изображения
# -----
jitter = .3
hue = .1
sat = 1.5
val = 1.5

# Масштабируем изображение
new_ar = w / h * rand(1 - jitter, 1 + jitter) / rand(1 - jitter, 1 + jitter)
scale = rand(.65, 2) 
print ('Коэффициент масштабирования: ', scale)
# Масштабируем изображение
if new_ar < 1:
    nh = int(scale * h)
    nw = int(nh * new_ar)
else:
    nw = int(scale * w)
    nh = int(nw / new_ar)
print ('Новый размер изображения: ',nw, nh)
image1 = image.resize((nw,nh), Image.BICUBIC) # Изменяем размер исходного изображения
plt.imshow(image1) # Рисуем изображение
# Out:
# Коэффициент масштабирования:  0.8227103304324666
# Новый размер изображения:  312 342

# %%
# Приводим к размеру 416 на 416 пикселей для модели YOLO и размещаем в случайном месте на изображении
dx = int(rand(0, w - nw))
dy = int(rand(0, h - nh))
new_image = Image.new('RGB', (w, h), (128,128,128))
new_image.paste(image1, (dx, dy))
image2 = new_image
plt.imshow(image2)

# %%
# Случаным образом отображаем изображение по горизонтале
flip = rand() < .5 # с вероятностью 50% получаем параметр отражения картинки
if flip: 
    image2 = image2.transpose(Image.FLIP_LEFT_RIGHT) # Если требуется, то отражаем картику по горизонтале
plt.imshow(image2) # Рисуем картинку

# %%
# Случайным образом меняем освещенность, экспозицию, гамму изображения
hue1 = rand(-hue, hue)
sat1 = rand(1, sat) if rand() < .5 else 1 / rand(1, sat)
val1 = rand(1, val) if rand() < .5 else 1 / rand(1, val)
x = rgb_to_hsv(np.array(image2) / 255.)
x[..., 0] += hue1
x[..., 0][x[..., 0] > 1] -= 1
x[..., 0][x[..., 0] < 0] += 1
x[..., 1] *= sat1
x[..., 2] *= val1
x[x > 1] = 1
x[x < 0] = 0
image_data = hsv_to_rgb(x) # numpy array, 0 to 1
print (image_data.shape) # Входные данные для модели YOLO, соответствующие изображению, размерностью 416х416х3
plt.imshow(image_data) # Рисуем изображение
# Out:
# (416, 416, 3)

# %%
# Корректируем параметры ограничивающей рамки
max_boxes = 5 # Устанавливаем максимальное кличество ограничивающих рамок
box_data = np.zeros((max_boxes,5)) # Массив будет хранить параметры ограничивающих рамок. Всего 5 параметров. Первые 4 - координаты minX, minY, maxX, maxY. 5-ый  - номер класса объекта ( в нашем случае всего один класс - самолеты)

box_mod = box.copy()
# Проходим те же модификации с ограничивающей рамкой, что и с изображением: масштабирование, отраженгие
box_mod[:, [0,2]] = box_mod[:, [0,2]] * nw / iw + dx
box_mod[:, [1,3]] = box_mod[:, [1,3]] * nh / ih + dy
if flip: 
    box_mod[:, [0,2]] = w - box_mod[:, [2,0]]
box_mod[:, 0:2][box_mod[:, 0:2] < 0] = 0
box_mod[:, 2][box_mod[:, 2] > w] = w # Если выходит за ширину
box_mod[:, 3][box_mod[:, 3] > h] = h # Если выходит за высотц
box_w = box_mod[:, 2] - box_mod[:, 0] 
box_h = box_mod[:, 3] - box_mod[:, 1]
box_mod = box_mod[np.logical_and(box_w > 1, box_h > 1)] # Отсекаем маленькие рамки

if len(box_mod) > max_boxes: 
    box_mod = box_mod[:max_boxes] # Если количество ограничивающих рамок больше установленного нами ранее
box_data[:len(box_mod)] = box_mod # Записываем в box_data информацию об ограничивающих рамках аугментированного изображения
print(box_data[0]) # Выводим параметры рамки для аугментированного изображения
img1 = ImageDraw.Draw(image2) # Создаем экземпляр изображения
for i in range(4): # Рисуем ограничивающую рамку
    img1.rectangle([box_data[0][0] + i, box_data[0][1] + i, box_data[0][2] - i, box_data[0][3] - i], outline = 'green')
plt.imshow(image2)
# Out:
# [100.  21. 296. 294.   0.]

# %%
num_layers = 3 # Количество анкоров на каждую сетку (в нашем случае каждая сетка будет иметь анкоры 3 разных размеров)
anchor_mask = [[6,7,8], [3,4,5], [0,1,2]] # Маска дял выбора анкоров
   
real_boxes = np.array(box_data, dtype='float32') # Переводим в numpy
input_shape = np.array((416,416), dtype='int32') # Переводим в numpy

# Определяем центр ограничивающей рамки и ее ширину и высоту
boxes_xy = (real_boxes[:,0:2] + real_boxes[:,2:4]) // 2
boxes_wh = real_boxes[..., 2:4] - real_boxes[..., 0:2]

print('Центр ограничивающей рамки: ', boxes_xy[0])
print('Ширина и высота ограничивающей рамки:', boxes_wh[0])
# Out:
# Центр ограничивающей рамки:  [198. 157.]
# Ширина и высота ограничивающей рамки: [196. 273.]

# %%
# Переводим параметры ограничивающей рамки в относительные координаты (от 0 до 1)
real_boxes[:, 0:2] = boxes_xy/input_shape[0]
real_boxes[:, 2:4] = boxes_wh/input_shape[1]
print(real_boxes[0])  # Первые два элемента - центр ограничивабщей рамки в относительных координатах, 
                      # Вторые два элемента - ширина и высотка ограничивающей рамки в относительных размерах
                      # Пятый элемент - класс объекта
# Out:
# [0.47596154 0.37740386 0.47115386 0.65625    0.        ]

# %%
# Создадим заготовку под входные слои y_true
cells = [13,26,52]
y_true = [np.zeros((cells[l],cells[l],len(anchor_mask[l]),5+num_classes),dtype='float32') for l in range(num_layers)]
print(y_true[0].shape)
print(y_true[1].shape)
print(y_true[2].shape)
# Таким образом получаем массив из трех сеток разных размеров (13х13, 26х26, 52х52), где каждая ячейка содержит
# три варинта пар анкоров и 5+1 параметр описания каждой из пар анкоров
# Out:
# (13, 13, 3, 6)
# (26, 26, 3, 6)
# (52, 52, 3, 6)

# %%
# из 9 анкоров фиксированного размера требуется найти тот, котоырй максимально охватывает ограничивающую рамку
# для этого пробегаем по всем имеющимся анкорам и считаем IoU всех вариантов

# Площадь, занятая ограничивающей рамкой
wh = boxes_wh[0, :] # Получаем ширину и высоту
box_area = wh[0] * wh[1] # Считаем площадь рамки
print (wh[0],'*',wh[1],'=', box_area)
# Out:
# 196.0 * 273.0 = 53508.0

# %%
# Площади, которые занимаю анкоры
anchor_area = anchors[:, 0] * anchors[:, 1]
print (anchor_area)
# Out:
# [   130    480    759   1830   2790   7021  10440  30888 121598]

# %%
# Получим новые параметры анкоров, значения которых не превышают значения высоты и ширины ограничивающей рамки
correct_anchors = []
for elem in anchors:
    correct_anchors.append ([min(elem[0], wh[0]), min(elem[1], wh[1])])
correct_anchors = np.array(correct_anchors)
print(correct_anchors)
# Площади, которые занимаю скорректированные анкоры
correct_anchors_area = correct_anchors[:,0] * correct_anchors[:,1]
print(correct_anchors_area)
# Out:
# [[ 10.  13.]
#  [ 16.  30.]
#  [ 33.  23.]
#  [ 30.  61.]
#  [ 62.  45.]
#  [ 59. 119.]
#  [116.  90.]
#  [156. 198.]
#  [196. 273.]]
# [  130.   480.   759.  1830.  2790.  7021. 10440. 30888. 53508.]

# %%
# Подсчитвываем iou всех вариантов
iou = correct_anchors_area / (box_area + anchor_area - correct_anchors_area)
print(iou)
# Out:
# [0.00242954 0.00897062 0.01418479 0.03420049 0.05214174 0.13121402
#  0.19511101 0.57725948 0.44004013]

# %%
# Определяем позицию лучшего анкора
best_anchor = np.argmax(iou, axis=-1)
print (best_anchor)
# Out:
# 7

# %%
print('Параметры ограничивающей рамки',real_boxes[0])
for l in range(num_layers): # Пробегаем по всем 3 уровням анкорв
    if best_anchor in anchor_mask[l]: # Если лучший анкор есть в l-ом элементе маски анкоров
        print('Уровень анкора =',l)
        i = np.floor(real_boxes[0,0]*cells[l]).astype('int32') # Определяем позицию ячейки по горизонтале
        print ('i =',i)    
        j = np.floor(real_boxes[0,1]*cells[l]).astype('int32') # Определяем позицию ячейки по вертикале
        print ('j =',j)    
        k = anchor_mask[l].index(best_anchor) # Определяем номре анкора в маске анкоров
        print('Номер поданкора =',k)    
        c = real_boxes[0, 4].astype('int32') # Записываем номер класса объекта
        print ('Номер класса =',c)    
        y_true[l][j, i, k, 0:4] = real_boxes[0, 0:4] # Записываем 4 параметра объекта - координаты центра, ширина и высота
        y_true[l][j, i, k, 4] = 1 # Записываем вероятность того, что найден объект (для обучающей выборки всегда 1)
        y_true[l][j, i, k, 5+c] = 1  # В позицию 5+с записываем класс объекта (ohe)
        break

print(y_true[l][j,i,...])
# Таким образом массив y_true состоит полностью из 0 и только в 0-ом элементе, который соответсвует сетке, разбиением 13 на 13,
# в ячейке (6,6), которая соответствует позиции центра ограничивающей рамки (0.5, 0.4903846) в позиции 1 анкора, 
# максимально охватывающего наш объект будет записана вся необходимая информация 
# [0.5       0.4903846 1.        0.46875   1.        1.       ]
# первые 4 элемента - координаты центр объекта, ширина и высота, 5ый элемент - вероятность объекта (1),
# 6ой-элемент - единица в позиции класса объекта
# Out:
# Параметры ограничивающей рамки [0.47596154 0.37740386 0.47115386 0.65625    0.        ]
# Уровень анкора = 0
# i = 6
# j = 4
# Номер поданкора = 1
# Номер класса = 0
# [[0.         0.         0.         0.         0.         0.        ]
#  [0.47596154 0.37740386 0.47115386 0.65625    1.         1.        ]
#  [0.         0.         0.         0.         0.         0.        ]]

# %% [markdown]
# ## Функции
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=3948

# %%
# Функция генерации данных
def data_generator(annotation_lines, batch_size, anchors, input_shape):
    n = len(annotation_lines) # Получаем количество элементов в словаре аннотаций
    i = 0 # Задаем начальный индекс
    while True:
        image_data = [] # Массив для хранения изображений 416х416
        box_data = [] # Массив для хранения bounding_box данных
        for b in range(batch_size): # Пробегаем по всему batch_size
            if i==0: # Если первая итерация цикла
                np.random.shuffle(annotation_lines) # Перемешиваем элементы
            image, box = augmentation(annotation_lines[i]) # Делаем аугментацию картинок и ограничивающих рамок
            image_data.append(image) # Добавляем полученную картинку в результирующий массив 
            box_data.append(box) # Добавляем полученную ограничивающую рамку в массив bounfing_box
            i = (i+1) % n # Обновляем значение индека (не превышая общего количества элементов)
        image_data = np.array(image_data) # Преобразуем в numpy
        box_data = np.array(box_data) # Преобразуем в numpy
        y_true = get_y(box_data, anchors, input_shape) # По значению ограничивающей рамки получаем y_true        
        yield [image_data, *y_true], np.zeros(batch_size) # Возвращаем порцию данных для обучения

# %%
# Случайная аугментация изображения
def augmentation(data):
    # Словарь с параметрами аугментации
    params = {
        'jitter' : .3,
        'hue'    : .1,
        'sat'    : 1.5,
        'val'    : 1.5
    }
    
    data = data.split() # Сплитим входную строку словаря
    image = Image.open(path + data[0]) # Открываем изображение самолета
    width_i, height_i = image.size # Получаем ширину и высоту оригинального изображения
    widht_shape, height_shape = input_shape[:2] # Получаем ширину и высоту входного изображения для модели RetinaNet
    
    # Получаем координаты ограничивающей рамки
    box = np.array([np.array(list(map(lambda x: int(float(x)),box.split(',')))) for box in data[1:]])
    
    # Случайным образом масштабируем изображение
    new_ar = widht_shape / height_shape * rand(1 - params['jitter'], 1 + params['jitter']) / rand(1 - params['jitter'], 1 + params['jitter'])
    scale = rand(.65, 2) 
    if new_ar < 1:        
        nh = int(scale * height_shape)
        nw = int(nh * new_ar)
    else:
        nw = int(scale * widht_shape)
        nh = int(nw / new_ar)
    image = image.resize((nw, nh), Image.BICUBIC)
    
    # Преобразуем картинку к input_shape и размещаем случайным образом
    dx = int(rand(0, widht_shape - nw))
    dy = int(rand(0, height_shape - nh))
    new_image = Image.new('RGB', (widht_shape, height_shape), (128,128,128))
    new_image.paste(image, (dx, dy))
    image = new_image
    
    # С вероятностью 50% отображаем по горизонтале
    flip = rand() < .5
    if flip:
        image = image.transpose(Image.FLIP_LEFT_RIGHT)
    
    # Случайным образом меняем освещенность, экспозицию, гамму изображения
    hue1 = rand(-params['hue'], params['hue'])
    sat1 = rand(1, params['sat']) if rand() < .5 else 1 / rand(1, params['sat'])
    val1 = rand(1, params['val']) if rand() < .5 else 1 / rand(1, params['val'])
    x = rgb_to_hsv(np.array(image) / 255.)
    x[..., 0] += hue1
    x[..., 0][x[..., 0] > 1] -= 1
    x[..., 0][x[..., 0] < 0] += 1
    x[..., 1] *= sat1
    x[..., 2] *= val1
    x[x > 1] = 1
    x[x < 0] = 0
    image_data = hsv_to_rgb(x) # Получаем окончательный массив
    
    max_boxes = 4 # Устанавливаем максимальное количество рамок на изображении
    # Корректируем параметры ограничивающей рамки в соответсвии с проведенными выше преобразованиями
    box_data = np.zeros((max_boxes,5)) # Создаем массив из нулей размерностью (max_boxes, 5) 
    if len(box)>0:                
        # Ресайзим и перемещаем
        box[:, [0,2]] = box[:, [0,2]] * nw/width_i + dx
        box[:, [1,3]] = box[:, [1,3]] * nh/height_i + dy
        # Отражаем по горизонтале
        if flip: box[:, [0,2]] = widht_shape - box[:, [2,0]]
        box[:, 0:2][box[:, 0:2]<0] = 0
        # Ограничиваем, если вышли за пределы input_shape
        box[:, 2][box[:, 2] > widht_shape] = widht_shape
        box[:, 3][box[:, 3] > height_shape] = height_shape
        # Считаем высоту и ширину рамок и оставляем только те, значения которых больше 1
        box_w = box[:, 2] - box[:, 0] # xRight - xLeft
        box_h = box[:, 3] - box[:, 1] # yBottom - yTop
        box = box[np.logical_and(box_w > 1, box_h > 1)]
        if len(box) > max_boxes: # Оставляем только max_boxes рамок
            box = box[:max_boxes]
        box_data[:len(box)] = box # Записываем данные в box_data
    
    # Возвращаем изменные изображение и ограничивающую рамку
    return image_data, box_data # Возвращаем аугментированные изображение и bounding_box

# %%
# Функция подсчета y
def get_y(true_boxes, anchors, input_shape):
    num_layers = len(anchors) // 3 # Получаем количество анкоров для каждого уровня сеток
    anchor_mask = [[6,7,8], [3,4,5], [0,1,2]] # Задаем маску анкоров для каждого уровня

    true_boxes = np.array(true_boxes, dtype='float32') # Преобразуем bounding_box в numpy
    input_shape = np.array(input_shape, dtype='int32') # Преобразуем input_shape в numpy
    boxes_xy = (true_boxes[..., 0:2] + true_boxes[..., 2:4]) // 2 # Получаем координаты центра bounding_box (xRight+xLeft / 2)
    boxes_wh = true_boxes[..., 2:4] - true_boxes[..., 0:2] # Получаем ширину и высоту bounding_box (xRight - xLeft)
    true_boxes[..., 0:2] = boxes_xy / input_shape[::-1] # Получаем координаты центра bounding_box в относительных координатах
    true_boxes[..., 2:4] = boxes_wh / input_shape[::-1] # Получаем высоту и ширину bounding_box В относительных значениях

    m = true_boxes.shape[0] # Получаем количество элементов в batch_size
    grid_shapes = [input_shape//{0:32, 1:16, 2:8}[l] for l in range(num_layers)] # Создаем список из трех элементов ([13, 13], [26, 26], [52, 52])

    # Создаем 0-вые списки для y_true
    # y_true[0].shape = (None, 13, 13, 3, 6)
    # y_true[1].shape = (None, 26, 26, 3, 6)
    # y_true[2].shape = (None, 52, 52, 3, 6)
    y_true = [np.zeros((m,grid_shapes[l][0],grid_shapes[l][1],len(anchor_mask[l]),5+num_classes),
        dtype='float32') for l in range(num_layers)]

    anchors = np.expand_dims(anchors, 0) # Добавляем размерность

    # Параметры для IoU
    anchor_maxes = anchors / 2. 
    anchor_mins = -anchor_maxes
    valid_mask = boxes_wh[..., 0] > 0

    for b in range(m):
        wh = boxes_wh[b, valid_mask[b]] # Получаем ширину и высоту текущего bounding_box
        if len(wh)==0: continue # Выходим если она нулевая
        wh = np.expand_dims(wh, -2) # Добавляем размерность
        
        # Параметры для IoU
        box_maxes = wh / 2.
        box_mins = -box_maxes
        
        intersect_mins = np.maximum(box_mins, anchor_mins) 
        intersect_maxes = np.minimum(box_maxes, anchor_maxes)
        intersect_wh = np.maximum(intersect_maxes - intersect_mins, 0.)
        intersect_area = intersect_wh[..., 0] * intersect_wh[..., 1]
        box_area = wh[..., 0] * wh[..., 1]
        anchor_area = anchors[..., 0] * anchors[..., 1]
        iou = intersect_area / (box_area + anchor_area - intersect_area)

        best_anchor = np.argmax(iou, axis=-1) # Находим лучшее значение iou для всех анкоров 

        for t, n in enumerate(best_anchor): 
            for l in range(num_layers):
                if n in anchor_mask[l]:
                    i = np.floor(true_boxes[b,t,0] * grid_shapes[l][1]).astype('int32')
                    j = np.floor(true_boxes[b,t,1] * grid_shapes[l][0]).astype('int32')
                    k = anchor_mask[l].index(n)
                    c = true_boxes[b,t, 4].astype('int32')
                    y_true[l][b, j, i, k, 0:4] = true_boxes[b,t, 0:4]
                    y_true[l][b, j, i, k, 4] = 1
                    y_true[l][b, j, i, k, 5+c] = 1
    return y_true

# %%
# Получение координат ограничивающей рамки
def getXY(image):
    image_red = np.array(image)[:,:,0]  # Считываем красный канал изображения
    indexes = np.where(image_red > 20) # Получаем индексы пискселей красного цвета
    
    # Возвращаем координаты ограничивающей рамки [Xmin, Ymin, Xmax, Ymax]
    return [min(indexes[1]), min(indexes[0]), max(indexes[1]), max(indexes[0]) ]

# Создание словаря {Имя файла: параметры файла}
def get_dict():
    i = 0
    dictionary = {} # Создаем пустой словарь
    files = os.listdir(path + 'Segment/') # Получаем список файлов
    class_id = 0 # Задаем параметр номера класса (у нас всего один класс "Самолет")
    for f in files:
        image = Image.open(path + 'Segment/'+f) # Открываем сегментированное изображение
        xy = getXY(image) # Получаем координаты ограничивающей рамки
        key = f # Получаем ключ словаря (имя файла)
        
        # Записываем значение в словарь
        dictionary[key] = 'Nail/'+key+' ' +str (xy[0]) +',' + str(xy[1])+','+str(xy[2])+','+str(xy[3])+','+str(class_id)
        i +=1
        if i == 100:
            break
    print ('Завершена обработка класса: ', name_classes[0]) # Выводим сообщение о заврешении обработки
        
    return dictionary # Возвращаем словарь

def rand(a=0, b=1):
    return np.random.rand()*(b-a) + a

# %% [markdown]
# ## Подготовка данных
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=4062

# %%
# Создаем словарь аннотаций (Формат: Имя_файла Xmin,Ymin,Xmax,Ymax,class_id)
startTime = time.time() # Засекаем время старта процесса создания словаря
dictionary = get_dict() # Вызываем функцию создания словаря

# Выводим сообщение о создании словаря и время, потраченное на создание словаря
print ('Словарь аннотаций создан! Время создания словаря:'+str(round(time.time() - startTime)) +'сек')
# Out:
# Завершена обработка класса:  Самолеты
# Словарь аннотаций создан! Время создания словаря:1сек

# %%
print ('Количество изображений:', len(dictionary)) # Отображаем количество элементов в словаре
# Out:
# Количество изображений: 52

# %%
dictionary_np = np.array(list(dictionary.values())) #Создаем numpy массив из значений словаря

# Выведем информацию из словаря и из его numpy представления
print (dictionary['nail_1.jpg'])
print(dictionary_np[0])
# Out:
# Nail/nail_1.jpg 63,0,304,409,0
# Nail/nail_39.jpg 74,42,603,388,0

# %%
val_split = 0.1 # Коэфициент разделения на обучающую и проверочную выборку

# Перемешаем значения в массиве
np.random.seed(17)
np.random.shuffle(dictionary_np)
np.random.seed(None)

num_val = int(len(dictionary_np) * val_split) # Количество элементов проверочной выборки
num_train = len(dictionary_np) - num_val # Количество элементов обучающей выборки
print (num_val)
print (num_train)
# Out:
# 5
# 47

# %% [markdown]
# ## Обучение с различными шагами

# %% [markdown]
# ### lr_value = 1e-3

# %% [markdown]
# #### Первые 100 эпох

# %%
lr_value = 1e-3 # Задаем размер шага обучения

# Компилируем модель
model_YOLO.compile(optimizer=Adam(lr=lr_value), loss={'yolo_loss': lambda y_true, y_pred: y_pred})
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
startTime = time.time() # Засекаем время начала процесса обучения
batch_size = 8 #Задаем размер пакета
model_filename = path +'weight/YOLO/YOLOv3__el1000__opt0.001__ep0_100.h5' # Указываем имя файла для сохранения модели
# Запускаем процесс обучения на 100 эпохах
history = model_YOLO.fit_generator(data_generator(dictionary_np[:num_train], batch_size, anchors, input_shape),
                    steps_per_epoch = max (1, num_train//batch_size),
                    validation_data = data_generator(dictionary_np[num_train:], batch_size, anchors, input_shape),
                    validation_steps = max (1, num_val//batch_size),
                    epochs = 100,
                    verbose = 1,
                    initial_epoch = 0
                    )

# Сохраним веса модели
model_YOLO.save_weights(model_filename)

# Сохраним значения ошибок в csv
loss = np.array(history.history['loss']) # Получаем значения ошибки на обучающей выборке
val_loss = np.array(history.history['val_loss']) # Получаем значения ошибки на проверочной выборке
pd.DataFrame(loss).to_csv(path+'csv/YOLO/loss__el1000_opt0.001__ep0_100.csv') # Сохраняем обучающую выборку
pd.DataFrame(val_loss).to_csv(path+'csv/YOLO/valloss__el1000_opt0.001__ep0_100.csv') # Сохраняем проверочную выборку

print ('Время обработки: '+ str(round(time.time() - startTime)) + 'сек') # Отображаем время, потраченное на процесс обучения
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 5/5 [==============================] - 47s 5s/step - loss: 12.4040 - val_loss: 5870017.5000
# Epoch 2/100
# 5/5 [==============================] - 5s 1s/step - loss: 10.9757 - val_loss: 35520143360.0000
# Epoch 3/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.9273 - val_loss: 15704340480.0000
# Epoch 4/100
# 5/5 [==============================] - 5s 1s/step - loss: 9.5896 - val_loss: 20979529728.0000
# Epoch 5/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.8895 - val_loss: 1414219520.0000
# Epoch 6/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.8187 - val_loss: 2150410496.0000
# Epoch 7/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.5355 - val_loss: 560143104.0000
# Epoch 8/100
# 5/5 [==============================] - 5s 1s/step - loss: 9.3072 - val_loss: 1526950528.0000
# Epoch 9/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.7566 - val_loss: 126752472.0000
# Epoch 10/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.2067 - val_loss: 7591043.0000
# Epoch 11/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.6826 - val_loss: 255608.3281
# Epoch 12/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.5342 - val_loss: 20837.7500
# Epoch 13/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.6245 - val_loss: 10706.3262
# Epoch 14/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.8613 - val_loss: 9021.6143
# Epoch 15/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.6094 - val_loss: 5143.8120
# Epoch 16/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.0464 - val_loss: 1718.8311
# Epoch 17/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.2133 - val_loss: 4729.0039
# Epoch 18/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.1493 - val_loss: 770.3561
# Epoch 19/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.4793 - val_loss: 348.2460
# Epoch 20/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.6098 - val_loss: 404.6369
# Epoch 21/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.1783 - val_loss: 250.9545
# Epoch 22/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.2033 - val_loss: 117.9730
# Epoch 23/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.7990 - val_loss: 17.9666
# Epoch 24/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.3100 - val_loss: 14.3292
# Epoch 25/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.0762 - val_loss: 11.5619
# Epoch 26/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.5607 - val_loss: 9.2500
# Epoch 27/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.4249 - val_loss: 12.2389
# Epoch 28/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.3862 - val_loss: 12.9216
# Epoch 29/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.3584 - val_loss: 9.7205
# Epoch 30/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6982 - val_loss: 10.7011
# Epoch 31/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.2880 - val_loss: 11.4094
# Epoch 32/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.6221 - val_loss: 10.6743
# Epoch 33/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.4716 - val_loss: 12.1568
# Epoch 34/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.4568 - val_loss: 10.5751
# Epoch 35/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.3005 - val_loss: 9.8505
# Epoch 36/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.5511 - val_loss: 9.4147
# Epoch 37/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.0890 - val_loss: 10.0114
# Epoch 38/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7297 - val_loss: 8.7784
# Epoch 39/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7969 - val_loss: 9.2120
# Epoch 40/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8450 - val_loss: 10.2102
# Epoch 41/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3900 - val_loss: 12.2161
# Epoch 42/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.1842 - val_loss: 10.2607
# Epoch 43/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7761 - val_loss: 7.9331
# Epoch 44/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7412 - val_loss: 10.7803
# Epoch 45/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7841 - val_loss: 8.6473
# Epoch 46/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3426 - val_loss: 9.6421
# Epoch 47/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7358 - val_loss: 9.5146
# Epoch 48/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8684 - val_loss: 9.8662
# Epoch 49/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.2183 - val_loss: 8.6467
# Epoch 50/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3441 - val_loss: 8.9434
# Epoch 51/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.0122 - val_loss: 9.1057
# Epoch 52/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.0756 - val_loss: 8.6563
# Epoch 53/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4729 - val_loss: 11.4388
# Epoch 54/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4250 - val_loss: 13.6093
# Epoch 55/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8190 - val_loss: 13.8634
# Epoch 56/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.5196 - val_loss: 10.8056
# Epoch 57/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8065 - val_loss: 8.7109
# Epoch 58/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.9661 - val_loss: 9.9898
# Epoch 59/100
# 5/5 [==============================] - 4s 1s/step - loss: 6.5829 - val_loss: 10.0240
# Epoch 60/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8426 - val_loss: 9.4759
# Epoch 61/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8549 - val_loss: 9.2959
# Epoch 62/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3372 - val_loss: 9.3368
# Epoch 63/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.1161 - val_loss: 8.8116
# Epoch 64/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6060 - val_loss: 11.2417
# Epoch 65/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6246 - val_loss: 8.4876
# Epoch 66/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.2766 - val_loss: 10.7827
# Epoch 67/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8004 - val_loss: 10.9224
# Epoch 68/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7230 - val_loss: 10.4445
# Epoch 69/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6859 - val_loss: 14.2126
# Epoch 70/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3655 - val_loss: 12.9117
# Epoch 71/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.9713 - val_loss: 12.3903
# Epoch 72/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0865 - val_loss: 8.4041
# Epoch 73/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8919 - val_loss: 9.1849
# Epoch 74/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.1124 - val_loss: 9.5443
# Epoch 75/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6260 - val_loss: 11.0824
# Epoch 76/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6112 - val_loss: 10.6503
# Epoch 77/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6929 - val_loss: 12.8291
# Epoch 78/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4923 - val_loss: 13.1529
# Epoch 79/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.0613 - val_loss: 12.6654
# Epoch 80/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.5038 - val_loss: 11.3700
# Epoch 81/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.9170 - val_loss: 12.4785
# Epoch 82/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8550 - val_loss: 14.5924
# Epoch 83/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7903 - val_loss: 11.7483
# Epoch 84/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6656 - val_loss: 13.5422
# Epoch 85/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4394 - val_loss: 15.6517
# Epoch 86/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.5051 - val_loss: 10.4410
# Epoch 87/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4758 - val_loss: 10.3426
# Epoch 88/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.1661 - val_loss: 11.6696
# Epoch 89/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.1428 - val_loss: 7.7456
# Epoch 90/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.5529 - val_loss: 10.2918
# Epoch 91/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3384 - val_loss: 8.8738
# Epoch 92/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.5518 - val_loss: 7.7570
# Epoch 93/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8011 - val_loss: 7.1792
# Epoch 94/100
# 5/5 [==============================] - 5s 1s/step - loss: 7.4484 - val_loss: 11.8385
# Epoch 95/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6990 - val_loss: 81.4421
# Epoch 96/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.2982 - val_loss: 9.3876
# Epoch 97/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4512 - val_loss: 10.1147
# Epoch 98/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.9057 - val_loss: 102.8072
# Epoch 99/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7169 - val_loss: 13.1108
# Epoch 100/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.2747 - val_loss: 10.7404
# Время обработки: 517сек

# %% [markdown]
# #### Еще 100 эпох на текущем шаге

# %%
#
# Если была перезагрузка сессии colab, то создаем модель, загружаем веса и  компилируем
#
model_weight =  path +'weight/YOLO/YOLOv3__el1000__opt0.001__ep0_100.h5' # Указываем файл с весами модели
model_YOLO = create_model(input_shape, num_anchors, use_weights=True, weights_path=model_weight)
lr_value = 1e-3 # Задаем размер шага обучения

# Компилируем модель
model_YOLO.compile(optimizer=Adam(lr=lr_value), loss={'yolo_loss':lambda y_true, y_pred: y_pred})
# Out:
# Создана модель YOLOv3. Количество классов: 1.
# Загружены веса из файла /content/drive/MyDrive/Baza/Object_detection/Nail/weight/YOLO/YOLOv3__el1000__opt0.001__ep0_100.h5.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
startTime = time.time() # Засекаем время начала процесса обучения
batch_size = 8 #Задаем размер пакета
model_filename = path +'weight/YOLO/YOLOv3__el1000__opt0.001__ep100_200.h5' # Указываем имя файла для сохранения модели

# Запускаем процесс обучения еще на 100 эпохах
history = model_YOLO.fit_generator(data_generator(dictionary_np[:num_train], batch_size, anchors, input_shape),
                    steps_per_epoch = max (1, num_train//batch_size),
                    validation_data = data_generator(dictionary_np[num_train:], batch_size, anchors, input_shape),
                    validation_steps = max (1, num_val//batch_size),
                    epochs = 200,
                    verbose = 1,
                    initial_epoch = 100
                    )

# Сохраним веса модели
model_YOLO.save_weights(model_filename)

# Сохраним значения ошибок в csv
loss = np.array(history.history['loss']) # Получаем значения ошибки на обучающей выборке
val_loss = np.array(history.history['val_loss']) # Получаем значения ошибки на проверочной выборке
pd.DataFrame(loss).to_csv(path+'csv/YOLO/loss__el1000_opt0.001__ep100_200.csv') # Сохраняем обучающую выборку
pd.DataFrame(val_loss).to_csv(path+'csv/YOLO/valloss__el1000_opt0.001__ep100_200.csv') # Сохраняем проверочную выборку

print ('Время обработки: '+ str(round(time.time() - startTime)) + 'сек') # Отображаем время, потраченное на процесс обучения
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 101/200
# 5/5 [==============================] - 18s 2s/step - loss: 7.2446 - val_loss: 11.3586
# Epoch 102/200
# 5/5 [==============================] - 5s 1s/step - loss: 8.0523 - val_loss: 9.2915
# Epoch 103/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.5982 - val_loss: 12.0908
# Epoch 104/200
# 5/5 [==============================] - 4s 1s/step - loss: 7.1203 - val_loss: 14.3812
# Epoch 105/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.3090 - val_loss: 25.2561
# Epoch 106/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8077 - val_loss: 11.1022
# Epoch 107/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6968 - val_loss: 11.1525
# Epoch 108/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0515 - val_loss: 15.7310
# Epoch 109/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.7370 - val_loss: 8.2219
# Epoch 110/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3085 - val_loss: 10.8319
# Epoch 111/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.7727 - val_loss: 11.2878
# Epoch 112/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.0638 - val_loss: 11.5581
# Epoch 113/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.5386 - val_loss: 13.3068
# Epoch 114/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.5114 - val_loss: 10.8558
# Epoch 115/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.1411 - val_loss: 12.4104
# Epoch 116/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6550 - val_loss: 15.1748
# Epoch 117/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.1998 - val_loss: 9.2762
# Epoch 118/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.8513 - val_loss: 12.4240
# Epoch 119/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8232 - val_loss: 9.2220
# Epoch 120/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6274 - val_loss: 11.1526
# Epoch 121/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4138 - val_loss: 14.2415
# Epoch 122/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6645 - val_loss: 13.5425
# Epoch 123/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.0992 - val_loss: 11.2113
# Epoch 124/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.2524 - val_loss: 7.3468
# Epoch 125/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3823 - val_loss: 8.0959
# Epoch 126/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2531 - val_loss: 8.2702
# Epoch 127/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4123 - val_loss: 9.0376
# Epoch 128/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4892 - val_loss: 11.7820
# Epoch 129/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0024 - val_loss: 8.0071
# Epoch 130/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4412 - val_loss: 10.1571
# Epoch 131/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3999 - val_loss: 11.5950
# Epoch 132/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.9487 - val_loss: 9.0301
# Epoch 133/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.7940 - val_loss: 8.2873
# Epoch 134/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.9512 - val_loss: 12.8843
# Epoch 135/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3408 - val_loss: 10.1647
# Epoch 136/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.0347 - val_loss: 11.3763
# Epoch 137/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8829 - val_loss: 15.1288
# Epoch 138/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.9816 - val_loss: 12.0690
# Epoch 139/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2118 - val_loss: 10.9587
# Epoch 140/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3128 - val_loss: 9.8037
# Epoch 141/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2093 - val_loss: 10.6331
# Epoch 142/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0037 - val_loss: 11.5020
# Epoch 143/200
# 5/5 [==============================] - 4s 1s/step - loss: 7.2272 - val_loss: 10.0658
# Epoch 144/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1112 - val_loss: 13.0461
# Epoch 145/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.1250 - val_loss: 21.4531
# Epoch 146/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.7970 - val_loss: 12.1364
# Epoch 147/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.0247 - val_loss: 22.3029
# Epoch 148/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.0036 - val_loss: 10.0538
# Epoch 149/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.3009 - val_loss: 11.2240
# Epoch 150/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.5999 - val_loss: 10.4568
# Epoch 151/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4027 - val_loss: 10.0777
# Epoch 152/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4989 - val_loss: 9.6239
# Epoch 153/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8367 - val_loss: 9.2996
# Epoch 154/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4551 - val_loss: 10.4914
# Epoch 155/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6035 - val_loss: 12.9368
# Epoch 156/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.8701 - val_loss: 11.7841
# Epoch 157/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3645 - val_loss: 10.6119
# Epoch 158/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1441 - val_loss: 10.3982
# Epoch 159/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4079 - val_loss: 9.9493
# Epoch 160/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.8161 - val_loss: 8.4474
# Epoch 161/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4271 - val_loss: 8.8293
# Epoch 162/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.3806 - val_loss: 9.1631
# Epoch 163/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.8070 - val_loss: 10.0745
# Epoch 164/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1581 - val_loss: 10.2364
# Epoch 165/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.5892 - val_loss: 8.9209
# Epoch 166/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.5228 - val_loss: 9.5433
# Epoch 167/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1273 - val_loss: 8.5803
# Epoch 168/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1424 - val_loss: 7.9669
# Epoch 169/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0005 - val_loss: 9.9054
# Epoch 170/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6758 - val_loss: 9.2066
# Epoch 171/200
# 5/5 [==============================] - 5s 1s/step - loss: 7.5047 - val_loss: 9.7561
# Epoch 172/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.5846 - val_loss: 13.1849
# Epoch 173/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8270 - val_loss: 8.9878
# Epoch 174/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1260 - val_loss: 8.9767
# Epoch 175/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2486 - val_loss: 9.0013
# Epoch 176/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.4503 - val_loss: 8.2268
# Epoch 177/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0893 - val_loss: 8.4631
# Epoch 178/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.7171 - val_loss: 10.5812
# Epoch 179/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0533 - val_loss: 12.1010
# Epoch 180/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.7709 - val_loss: 10.1066
# Epoch 181/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1298 - val_loss: 9.4672
# Epoch 182/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6486 - val_loss: 10.3000
# Epoch 183/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1262 - val_loss: 10.6537
# Epoch 184/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6969 - val_loss: 8.9415
# Epoch 185/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2543 - val_loss: 12.0540
# Epoch 186/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2397 - val_loss: 11.1433
# Epoch 187/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.9768 - val_loss: 10.7604
# Epoch 188/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.2302 - val_loss: 17.4726
# Epoch 189/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.6718 - val_loss: 8.8404
# Epoch 190/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6013 - val_loss: 9.0033
# Epoch 191/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.7411 - val_loss: 9.8519
# Epoch 192/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.5501 - val_loss: 9.4950
# Epoch 193/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.0976 - val_loss: 16.9270
# Epoch 194/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.6996 - val_loss: 9.0934
# Epoch 195/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8560 - val_loss: 40.5140
# Epoch 196/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1295 - val_loss: 72.1402
# Epoch 197/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.9038 - val_loss: 10.2838
# Epoch 198/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.9594 - val_loss: 17.9380
# Epoch 199/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.9418 - val_loss: 12.0835
# Epoch 200/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.8495 - val_loss: 12.1616
# Время обработки: 491сек

# %% [markdown]
# ### lr_value = 1e-4

# %% [markdown]
# #### Первые 100 эпох

# %%
#
# Если была перезагрузка сессии colab, то создаем модель, загружаем веса и  компилируем
#

model_weight =  path +'weight/YOLO/YOLOv3__el1000__opt0.001__ep100_200.h5' # Указываем файл с весами модели
model_YOLO = create_model(input_shape, num_anchors, use_weights=True, weights_path=model_weight)
model_YOLO.load_weights(model_weight) # Загружаем посчитанные веса модели
lr_value = 1e-4 # Задаем размер шага обучения

# Компилируем модель
model_YOLO.compile(optimizer=Adam(lr=lr_value), loss={'yolo_loss':lambda y_true, y_pred: y_pred})
# Out:
# Создана модель YOLOv3. Количество классов: 1.
# Загружены веса из файла /content/drive/MyDrive/Baza/Object_detection/Nail/weight/YOLO/YOLOv3__el1000__opt0.001__ep100_200.h5.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
startTime = time.time() # Засекаем время начала процесса обучения
batch_size = 8 #Задаем размер пакета
model_filename = path +'weight/YOLO/YOLOv3__el1000__opt0.0001__ep0_100.h5' # Указываем имя файла для сохранения модели

# Запускаем процесс обучения на 100 эпохах
history = model_YOLO.fit_generator(data_generator(dictionary_np[:num_train], batch_size, anchors, input_shape),
                    steps_per_epoch = max (1, num_train//batch_size),
                    validation_data = data_generator(dictionary_np[num_train:], batch_size, anchors, input_shape),
                    validation_steps = max (1, num_val//batch_size),
                    epochs = 100,
                    verbose = 1,
                    initial_epoch = 0
                    )

# Сохраним веса модели
model_YOLO.save_weights(model_filename)

# Сохраним значения ошибок в csv
loss = np.array(history.history['loss']) # Получаем значения ошибки на обучающей выборке
val_loss = np.array(history.history['val_loss']) # Получаем значения ошибки на проверочной выборке
pd.DataFrame(loss).to_csv(path+'csv/YOLO/loss__el1000_opt0.0001__ep0_100.csv') # Сохраняем обучающую выборку
pd.DataFrame(val_loss).to_csv(path+'csv/YOLO/valloss__el1000_opt0.0001__ep0_100.csv') # Сохраняем проверочную выборку

print ('Время обработки: '+ str(round(time.time() - startTime)) + 'сек') # Отображаем время, потраченное на процесс обучения
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 5/5 [==============================] - 18s 2s/step - loss: 6.7151 - val_loss: 12.3778
# Epoch 2/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6167 - val_loss: 13.2424
# Epoch 3/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0472 - val_loss: 14.1491
# Epoch 4/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3324 - val_loss: 10.2312
# Epoch 5/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8545 - val_loss: 11.5233
# Epoch 6/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4307 - val_loss: 10.9880
# Epoch 7/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0611 - val_loss: 8.4728
# Epoch 8/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4264 - val_loss: 10.2805
# Epoch 9/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.8849 - val_loss: 10.4919
# Epoch 10/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.5635 - val_loss: 9.6997
# Epoch 11/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8066 - val_loss: 9.4201
# Epoch 12/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8756 - val_loss: 11.4853
# Epoch 13/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.9065 - val_loss: 8.1566
# Epoch 14/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0715 - val_loss: 9.0274
# Epoch 15/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0716 - val_loss: 8.2963
# Epoch 16/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.6111 - val_loss: 10.0887
# Epoch 17/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6629 - val_loss: 8.3930
# Epoch 18/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.7287 - val_loss: 8.5295
# Epoch 19/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5366 - val_loss: 9.0268
# Epoch 20/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.9241 - val_loss: 10.1644
# Epoch 21/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4789 - val_loss: 9.2252
# Epoch 22/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.3260 - val_loss: 9.7290
# Epoch 23/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5041 - val_loss: 7.6026
# Epoch 24/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5708 - val_loss: 10.1659
# Epoch 25/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0901 - val_loss: 8.5834
# Epoch 26/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9721 - val_loss: 10.5874
# Epoch 27/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4127 - val_loss: 7.9005
# Epoch 28/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3016 - val_loss: 9.6337
# Epoch 29/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8636 - val_loss: 9.9783
# Epoch 30/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6817 - val_loss: 8.8482
# Epoch 31/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2966 - val_loss: 8.4672
# Epoch 32/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4169 - val_loss: 10.3376
# Epoch 33/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.4948 - val_loss: 8.0262
# Epoch 34/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4124 - val_loss: 9.0724
# Epoch 35/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3892 - val_loss: 8.2549
# Epoch 36/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6979 - val_loss: 7.6746
# Epoch 37/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4028 - val_loss: 9.7326
# Epoch 38/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5770 - val_loss: 9.2696
# Epoch 39/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4593 - val_loss: 10.1880
# Epoch 40/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1713 - val_loss: 8.0623
# Epoch 41/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4661 - val_loss: 8.5696
# Epoch 42/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3384 - val_loss: 7.1793
# Epoch 43/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4965 - val_loss: 8.6964
# Epoch 44/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3055 - val_loss: 9.9913
# Epoch 45/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.2281 - val_loss: 9.7801
# Epoch 46/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6198 - val_loss: 9.2545
# Epoch 47/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4060 - val_loss: 9.1157
# Epoch 48/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.7504 - val_loss: 7.9879
# Epoch 49/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9750 - val_loss: 9.6346
# Epoch 50/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6997 - val_loss: 8.6184
# Epoch 51/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8276 - val_loss: 8.7953
# Epoch 52/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5896 - val_loss: 8.2979
# Epoch 53/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5695 - val_loss: 8.8145
# Epoch 54/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9886 - val_loss: 8.0891
# Epoch 55/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2844 - val_loss: 8.2503
# Epoch 56/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.8013 - val_loss: 8.1654
# Epoch 57/100
# 5/5 [==============================] - 5s 1s/step - loss: 6.0746 - val_loss: 9.6279
# Epoch 58/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5494 - val_loss: 8.7885
# Epoch 59/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2019 - val_loss: 7.8538
# Epoch 60/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3899 - val_loss: 8.3678
# Epoch 61/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9825 - val_loss: 8.9920
# Epoch 62/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2968 - val_loss: 9.5647
# Epoch 63/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9953 - val_loss: 8.8413
# Epoch 64/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6529 - val_loss: 9.4902
# Epoch 65/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.7618 - val_loss: 9.5673
# Epoch 66/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.9983 - val_loss: 8.2027
# Epoch 67/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3960 - val_loss: 10.7795
# Epoch 68/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3350 - val_loss: 10.7720
# Epoch 69/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2698 - val_loss: 7.9752
# Epoch 70/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1124 - val_loss: 7.4949
# Epoch 71/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.0063 - val_loss: 8.6081
# Epoch 72/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3500 - val_loss: 8.6781
# Epoch 73/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.9716 - val_loss: 9.8144
# Epoch 74/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3825 - val_loss: 9.5633
# Epoch 75/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4509 - val_loss: 8.5209
# Epoch 76/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1292 - val_loss: 9.5859
# Epoch 77/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.4475 - val_loss: 7.9412
# Epoch 78/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3087 - val_loss: 8.0765
# Epoch 79/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9302 - val_loss: 7.6355
# Epoch 80/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9790 - val_loss: 8.4674
# Epoch 81/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9789 - val_loss: 8.7026
# Epoch 82/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8527 - val_loss: 8.3828
# Epoch 83/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2938 - val_loss: 8.2267
# Epoch 84/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.6934 - val_loss: 9.0127
# Epoch 85/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6530 - val_loss: 9.5002
# Epoch 86/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3269 - val_loss: 9.1102
# Epoch 87/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9994 - val_loss: 9.5290
# Epoch 88/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8669 - val_loss: 10.4874
# Epoch 89/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3381 - val_loss: 8.4505
# Epoch 90/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1765 - val_loss: 7.4419
# Epoch 91/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.0195 - val_loss: 8.6419
# Epoch 92/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5021 - val_loss: 7.6407
# Epoch 93/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9546 - val_loss: 9.2716
# Epoch 94/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7458 - val_loss: 10.7508
# Epoch 95/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.0915 - val_loss: 8.1851
# Epoch 96/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.0186 - val_loss: 9.2388
# Epoch 97/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2442 - val_loss: 8.4325
# Epoch 98/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1619 - val_loss: 9.1759
# Epoch 99/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3927 - val_loss: 10.0808
# Epoch 100/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9445 - val_loss: 10.5655
# Время обработки: 494сек

# %% [markdown]
# #### Еще 100 эпох

# %%
#
# Если была перезагрузка сессии colab, то создаем модель, загружаем веса и  компилируем
#
model_weight =  path +'weight/YOLO/YOLOv3__el1000__opt0.0001__ep0_100.h5' # Указываем файл с весами модели
model_YOLO = create_model(input_shape, num_anchors, use_weights=True, weights_path=model_weight)
model_YOLO.load_weights(model_weight) # Загружаем посчитанные веса модели
lr_value = 1e-4 # Задаем размер шага обучения

# Компилируем модель
model_YOLO.compile(optimizer=Adam(lr=lr_value), loss={'yolo_loss':lambda y_true, y_pred: y_pred})
# Out:
# Создана модель YOLOv3. Количество классов: 1.
# Загружены веса из файла /content/drive/MyDrive/Baza/Object_detection/Nail/weight/YOLO/YOLOv3__el1000__opt0.0001__ep0_100.h5.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
startTime = time.time() # Засекаем время начала процесса обучения
batch_size = 8 #Задаем размер пакета
model_filename = path +'weight/YOLO/YOLOv3__el1000__opt0.0001__ep100_200.h5' # Указываем имя файла для сохранения модели

# Запускаем процесс обучения еще на 100 эпохах
history = model_YOLO.fit_generator(data_generator(dictionary_np[:num_train], batch_size, anchors, input_shape),
                    steps_per_epoch = max (1, num_train//batch_size),
                    validation_data = data_generator(dictionary_np[num_train:], batch_size, anchors, input_shape),
                    validation_steps = max (1, num_val//batch_size),
                    epochs = 200,
                    verbose = 1,
                    initial_epoch = 100
                    )

# Сохраним веса модели
model_YOLO.save_weights(model_filename)

# Сохраним значения ошибок в csv
loss = np.array(history.history['loss']) # Получаем значения ошибки на обучающей выборке
val_loss = np.array(history.history['val_loss']) # Получаем значения ошибки на проверочной выборке
pd.DataFrame(loss).to_csv(path+'csv/YOLO/loss__el1000_opt0.0001__ep100_200.csv') # Сохраняем обучающую выборку
pd.DataFrame(val_loss).to_csv(path+'csv/YOLO/valloss__el1000_opt0.0001__ep100_200.csv') # Сохраняем проверочную выборку

print ('Время обработки: '+ str(round(time.time() - startTime)) + 'сек') # Отображаем время, потраченное на процесс обучения
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 101/200
# 5/5 [==============================] - 18s 2s/step - loss: 5.3340 - val_loss: 9.5181
# Epoch 102/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.2520 - val_loss: 9.1251
# Epoch 103/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3270 - val_loss: 9.3134
# Epoch 104/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1054 - val_loss: 8.9346
# Epoch 105/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.2306 - val_loss: 10.7805
# Epoch 106/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6695 - val_loss: 8.4768
# Epoch 107/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.7101 - val_loss: 9.0733
# Epoch 108/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0135 - val_loss: 7.5933
# Epoch 109/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0665 - val_loss: 8.2295
# Epoch 110/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.9229 - val_loss: 8.9749
# Epoch 111/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0272 - val_loss: 9.8973
# Epoch 112/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3015 - val_loss: 9.3489
# Epoch 113/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0295 - val_loss: 8.8482
# Epoch 114/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.4174 - val_loss: 9.0162
# Epoch 115/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6116 - val_loss: 7.9337
# Epoch 116/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.8243 - val_loss: 8.5495
# Epoch 117/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6216 - val_loss: 10.4128
# Epoch 118/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.9500 - val_loss: 10.9372
# Epoch 119/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.6166 - val_loss: 9.0109
# Epoch 120/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8697 - val_loss: 6.8220
# Epoch 121/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.4008 - val_loss: 7.8793
# Epoch 122/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.2081 - val_loss: 9.5329
# Epoch 123/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.5143 - val_loss: 8.8323
# Epoch 124/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.4043 - val_loss: 8.0150
# Epoch 125/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5836 - val_loss: 8.5056
# Epoch 126/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8120 - val_loss: 8.5014
# Epoch 127/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.8119 - val_loss: 10.9082
# Epoch 128/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.2707 - val_loss: 7.1739
# Epoch 129/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.6128 - val_loss: 8.4901
# Epoch 130/200
# 5/5 [==============================] - 5s 1s/step - loss: 6.1797 - val_loss: 9.7325
# Epoch 131/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0086 - val_loss: 7.2849
# Epoch 132/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8199 - val_loss: 6.7471
# Epoch 133/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0308 - val_loss: 8.3618
# Epoch 134/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1552 - val_loss: 8.7074
# Epoch 135/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.9452 - val_loss: 7.7023
# Epoch 136/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.7073 - val_loss: 9.6841
# Epoch 137/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5685 - val_loss: 9.5590
# Epoch 138/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0019 - val_loss: 9.4997
# Epoch 139/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3569 - val_loss: 9.7343
# Epoch 140/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1476 - val_loss: 9.5414
# Epoch 141/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.2377 - val_loss: 9.1068
# Epoch 142/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1924 - val_loss: 11.3490
# Epoch 143/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.9027 - val_loss: 9.0200
# Epoch 144/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6951 - val_loss: 7.9658
# Epoch 145/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.4145 - val_loss: 9.0168
# Epoch 146/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0938 - val_loss: 7.8518
# Epoch 147/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3460 - val_loss: 10.3800
# Epoch 148/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8961 - val_loss: 8.5449
# Epoch 149/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3267 - val_loss: 8.8379
# Epoch 150/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.0288 - val_loss: 12.4418
# Epoch 151/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3357 - val_loss: 8.9645
# Epoch 152/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.2237 - val_loss: 7.9408
# Epoch 153/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1680 - val_loss: 7.5320
# Epoch 154/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3374 - val_loss: 7.7912
# Epoch 155/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8606 - val_loss: 9.2171
# Epoch 156/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.7008 - val_loss: 11.2784
# Epoch 157/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6390 - val_loss: 12.1796
# Epoch 158/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6462 - val_loss: 9.5956
# Epoch 159/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.9247 - val_loss: 8.5046
# Epoch 160/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6791 - val_loss: 9.3103
# Epoch 161/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5560 - val_loss: 9.0908
# Epoch 162/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.7766 - val_loss: 8.7673
# Epoch 163/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3101 - val_loss: 8.9967
# Epoch 164/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.4601 - val_loss: 10.5666
# Epoch 165/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1821 - val_loss: 9.1197
# Epoch 166/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6853 - val_loss: 8.7363
# Epoch 167/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.2939 - val_loss: 6.5646
# Epoch 168/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5426 - val_loss: 7.0340
# Epoch 169/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.7325 - val_loss: 8.9426
# Epoch 170/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0820 - val_loss: 7.4865
# Epoch 171/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.4241 - val_loss: 7.6711
# Epoch 172/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5528 - val_loss: 7.7949
# Epoch 173/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3868 - val_loss: 8.2640
# Epoch 174/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.7824 - val_loss: 7.3712
# Epoch 175/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8769 - val_loss: 9.2441
# Epoch 176/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.8474 - val_loss: 8.2873
# Epoch 177/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3093 - val_loss: 9.0552
# Epoch 178/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3739 - val_loss: 8.3756
# Epoch 179/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5324 - val_loss: 7.7284
# Epoch 180/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1838 - val_loss: 8.5612
# Epoch 181/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.5417 - val_loss: 9.7883
# Epoch 182/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3253 - val_loss: 8.0306
# Epoch 183/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5998 - val_loss: 8.8818
# Epoch 184/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0078 - val_loss: 7.5160
# Epoch 185/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6994 - val_loss: 9.4982
# Epoch 186/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.0487 - val_loss: 7.5904
# Epoch 187/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.1945 - val_loss: 8.1369
# Epoch 188/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.6824 - val_loss: 10.5926
# Epoch 189/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3227 - val_loss: 6.7572
# Epoch 190/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.1618 - val_loss: 9.5595
# Epoch 191/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.3562 - val_loss: 8.2381
# Epoch 192/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.1477 - val_loss: 10.3782
# Epoch 193/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3373 - val_loss: 7.3419
# Epoch 194/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.9513 - val_loss: 9.8356
# Epoch 195/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.7149 - val_loss: 8.3246
# Epoch 196/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.5494 - val_loss: 10.9565
# Epoch 197/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.2752 - val_loss: 7.7506
# Epoch 198/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.3957 - val_loss: 8.7993
# Epoch 199/200
# 5/5 [==============================] - 5s 1s/step - loss: 4.4423 - val_loss: 8.4260
# Epoch 200/200
# 5/5 [==============================] - 5s 1s/step - loss: 5.4027 - val_loss: 6.5367
# Время обработки: 488сек

# %% [markdown]
# ### lr_value = 1e-5

# %% [markdown]
# #### Первые 100 эпох

# %%
#
# Если была перезагрузка сессии colab, то создаем модель, загружаем веса и  компилируем
#
model_weight =  path +'weight/YOLO/YOLOv3__el1000__opt0.0001__ep100_200.h5' # Указываем файл с весами модели
model_YOLO = create_model(input_shape, num_anchors, use_weights=True, weights_path=model_weight)
model_YOLO.load_weights(model_weight) # Загружаем посчитанные веса модели
print ('{} загружены.'.format(model_weight))
lr_value = 1e-5 # Задаем размер шага обучения

# Компилируем модель
model_YOLO.compile(optimizer=Adam(lr=lr_value), loss={'yolo_loss':lambda y_true, y_pred: y_pred})
# Out:
# Создана модель YOLOv3. Количество классов: 1.
# Загружены веса из файла /content/drive/MyDrive/Baza/Object_detection/Nail/weight/YOLO/YOLOv3__el1000__opt0.0001__ep100_200.h5.
# /content/drive/MyDrive/Baza/Object_detection/Nail/weight/YOLO/YOLOv3__el1000__opt0.0001__ep100_200.h5 загружены.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
startTime = time.time() # Засекаем время начала процесса обучения
batch_size = 8 #Задаем размер пакета
model_filename = path +'weight/YOLO/YOLOv3__el1000__opt0.00001__ep0_100.h5' # Указываем имя файла для сохранения модели

# Запускаем процесс обучения на 100 эпохах
history = model_YOLO.fit_generator(data_generator(dictionary_np[:num_train], batch_size, anchors, input_shape),
                    steps_per_epoch = max (1, num_train//batch_size),
                    validation_data = data_generator(dictionary_np[num_train:], batch_size, anchors, input_shape),
                    validation_steps = max (1, num_val//batch_size),
                    epochs = 100,
                    verbose = 1,
                    initial_epoch = 0
                    )

# Сохраним веса модели
model_YOLO.save_weights(model_filename)

# Сохраним значения ошибок в csv
loss = np.array(history.history['loss']) # Получаем значения ошибки на обучающей выборке
val_loss = np.array(history.history['val_loss']) # Получаем значения ошибки на проверочной выборке
pd.DataFrame(loss).to_csv(path+'csv/YOLO/loss__el1000_opt0.00001__ep0_100.csv') # Сохраняем обучающую выборку
pd.DataFrame(val_loss).to_csv(path+'csv/YOLO/valloss__el1000_opt0.00001__ep0_100.csv') # Сохраняем проверочную выборку

print ('Время обработки: '+ str(round(time.time() - startTime)) + 'сек') # Отображаем время, потраченное на процесс обучения
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 5/5 [==============================] - 18s 2s/step - loss: 4.5306 - val_loss: 9.1629
# Epoch 2/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7763 - val_loss: 9.7682
# Epoch 3/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.1325 - val_loss: 8.8615
# Epoch 4/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1482 - val_loss: 7.1657
# Epoch 5/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6288 - val_loss: 8.2673
# Epoch 6/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2312 - val_loss: 8.4795
# Epoch 7/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2180 - val_loss: 8.5306
# Epoch 8/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7525 - val_loss: 7.7233
# Epoch 9/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5777 - val_loss: 10.6708
# Epoch 10/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5034 - val_loss: 7.1102
# Epoch 11/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7438 - val_loss: 9.4546
# Epoch 12/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3978 - val_loss: 10.6085
# Epoch 13/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2158 - val_loss: 9.6074
# Epoch 14/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6803 - val_loss: 8.0148
# Epoch 15/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3170 - val_loss: 9.5316
# Epoch 16/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9965 - val_loss: 7.3555
# Epoch 17/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8462 - val_loss: 8.7897
# Epoch 18/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8600 - val_loss: 9.6223
# Epoch 19/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8114 - val_loss: 6.8182
# Epoch 20/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3220 - val_loss: 7.8640
# Epoch 21/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5452 - val_loss: 9.1850
# Epoch 22/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5067 - val_loss: 8.9389
# Epoch 23/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9535 - val_loss: 6.6171
# Epoch 24/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3287 - val_loss: 7.2152
# Epoch 25/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9117 - val_loss: 6.8618
# Epoch 26/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7005 - val_loss: 7.6190
# Epoch 27/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2439 - val_loss: 7.2943
# Epoch 28/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8261 - val_loss: 9.5634
# Epoch 29/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7819 - val_loss: 6.2633
# Epoch 30/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9824 - val_loss: 6.7401
# Epoch 31/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6269 - val_loss: 8.8930
# Epoch 32/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2827 - val_loss: 7.5894
# Epoch 33/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5459 - val_loss: 7.4097
# Epoch 34/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4678 - val_loss: 8.4593
# Epoch 35/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8635 - val_loss: 8.1880
# Epoch 36/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5917 - val_loss: 8.4840
# Epoch 37/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2696 - val_loss: 10.0943
# Epoch 38/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7395 - val_loss: 6.7379
# Epoch 39/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.1432 - val_loss: 9.7340
# Epoch 40/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9766 - val_loss: 7.9708
# Epoch 41/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5732 - val_loss: 9.2577
# Epoch 42/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3313 - val_loss: 8.6621
# Epoch 43/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5569 - val_loss: 9.4221
# Epoch 44/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8353 - val_loss: 6.8130
# Epoch 45/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.0890 - val_loss: 8.6573
# Epoch 46/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1386 - val_loss: 8.0110
# Epoch 47/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3238 - val_loss: 7.3242
# Epoch 48/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8670 - val_loss: 7.4980
# Epoch 49/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5397 - val_loss: 6.5481
# Epoch 50/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4135 - val_loss: 6.8394
# Epoch 51/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5134 - val_loss: 10.1953
# Epoch 52/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6371 - val_loss: 9.1848
# Epoch 53/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2113 - val_loss: 8.4012
# Epoch 54/100
# 5/5 [==============================] - 5s 1s/step - loss: 3.9985 - val_loss: 8.1047
# Epoch 55/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5188 - val_loss: 9.2462
# Epoch 56/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1254 - val_loss: 8.5900
# Epoch 57/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1885 - val_loss: 8.7050
# Epoch 58/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4024 - val_loss: 8.1887
# Epoch 59/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7433 - val_loss: 7.1506
# Epoch 60/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6712 - val_loss: 9.1716
# Epoch 61/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4985 - val_loss: 7.0861
# Epoch 62/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3032 - val_loss: 7.1280
# Epoch 63/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1495 - val_loss: 10.5025
# Epoch 64/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2648 - val_loss: 7.1934
# Epoch 65/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.9236 - val_loss: 7.3141
# Epoch 66/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5329 - val_loss: 8.0103
# Epoch 67/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2466 - val_loss: 9.6092
# Epoch 68/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.0475 - val_loss: 9.0260
# Epoch 69/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4009 - val_loss: 8.6311
# Epoch 70/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7724 - val_loss: 7.8310
# Epoch 71/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3149 - val_loss: 10.0131
# Epoch 72/100
# 5/5 [==============================] - 4s 1s/step - loss: 4.6187 - val_loss: 7.3108
# Epoch 73/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3702 - val_loss: 8.7637
# Epoch 74/100
# 5/5 [==============================] - 4s 1s/step - loss: 4.5041 - val_loss: 8.0514
# Epoch 75/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7692 - val_loss: 7.0171
# Epoch 76/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4708 - val_loss: 7.0522
# Epoch 77/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1651 - val_loss: 7.9977
# Epoch 78/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7261 - val_loss: 7.3649
# Epoch 79/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3266 - val_loss: 7.4830
# Epoch 80/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6191 - val_loss: 8.8094
# Epoch 81/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3790 - val_loss: 9.1096
# Epoch 82/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2485 - val_loss: 6.8298
# Epoch 83/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7425 - val_loss: 7.0876
# Epoch 84/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1798 - val_loss: 7.8506
# Epoch 85/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7919 - val_loss: 8.1914
# Epoch 86/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6873 - val_loss: 9.1962
# Epoch 87/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.3419 - val_loss: 9.2171
# Epoch 88/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.1019 - val_loss: 7.3118
# Epoch 89/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2091 - val_loss: 8.0344
# Epoch 90/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.7140 - val_loss: 8.2108
# Epoch 91/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.4917 - val_loss: 7.3027
# Epoch 92/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8572 - val_loss: 8.3427
# Epoch 93/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3932 - val_loss: 6.8554
# Epoch 94/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.3307 - val_loss: 7.2144
# Epoch 95/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.2763 - val_loss: 7.3813
# Epoch 96/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.1273 - val_loss: 7.2268
# Epoch 97/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.8169 - val_loss: 8.8792
# Epoch 98/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6325 - val_loss: 8.6009
# Epoch 99/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.5144 - val_loss: 8.7882
# Epoch 100/100
# 5/5 [==============================] - 5s 1s/step - loss: 4.6617 - val_loss: 7.4648
# Время обработки: 489сек

# %% [markdown]
# ### Графики

# %% [markdown]
# #### Первые 100 эпох

# %%
# Первые 100 эпох
loss1 = pd.read_csv(path+'csv/YOLO/loss__el1000_opt0.001__ep0_100.csv')
values = loss1.values[:, 1]
plt.plot(values[10:100], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', values.min())
print ('last:', values[-1])
# Out:
# min: 5.665596961975098
# last: 6.274748802185059

# %% [markdown]
# #### 200 эпох

# %%
# 200 эпох
loss2 = pd.read_csv(path+'csv/YOLO/loss__el1000_opt0.001__ep100_200.csv')
values2 = loss2.values[:, 1]
full_loss = np.concatenate((values, values2))
plt.plot(full_loss[10:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
print ('last:', full_loss[-1])
# Out:
# min: 5.550109386444092
# last: 6.849520683288574

# %% [markdown]
# #### 300 эпох

# %%
# 300 эпох
loss3 = pd.read_csv(path+'csv/YOLO/loss__el1000_opt0.0001__ep0_100.csv')
values3 = loss3.values[:, 1]
full_loss = np.concatenate((full_loss, values3))
plt.plot(full_loss[10:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
print ('last:', full_loss[-1])
# Out:
# min: 4.653000831604004
# last: 4.944539546966553

# %%
plt.plot(full_loss[-80:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
# Out:
# min: 4.653000831604004

# %% [markdown]
# #### 400 эпох

# %%
# 400 эпох
loss4 = pd.read_csv(path+'csv/YOLO/loss__el1000_opt0.0001__ep100_200.csv')
values4 = loss4.values[:, 1]
full_loss = np.concatenate((full_loss, values4))
plt.plot(full_loss[10:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
print ('last:', full_loss[-1])
# Out:
# min: 4.0288405418396005
# last: 5.402738571166992

# %%
plt.plot(full_loss[-80:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
print ('last:', full_loss[-1])
# Out:
# min: 4.0288405418396005
# last: 5.402738571166992

# %% [markdown]
# #### 500 эпох

# %%
# 500 эпох
loss5 = pd.read_csv(path+'csv/YOLO/loss__el1000_opt0.00001__ep0_100.csv')
values5 = loss5.values[:, 1]
full_loss = np.concatenate((full_loss, values5))
plt.plot(full_loss[10:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
print ('last:', full_loss[-1])
# Out:
# min: 3.998474597930908
# last: 4.66174840927124

# %%
plt.plot(full_loss[-80:], 
         label='Loss на обучающем наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
print ('min:', full_loss.min())
print ('last:', full_loss[-1])
# Out:
# min: 3.998474597930908
# last: 4.66174840927124

# %% [markdown]
# #### На тестовой выборке

# %%
val_loss1 = pd.read_csv(path+'csv/YOLO/valloss__el1000_opt0.001__ep0_100.csv').values[:,1]
val_loss2 = pd.read_csv(path+'csv/YOLO/valloss__el1000_opt0.001__ep100_200.csv').values[:,1]
val_loss3 = pd.read_csv(path+'csv/YOLO/valloss__el1000_opt0.0001__ep0_100.csv').values[:,1]
val_loss4= pd.read_csv(path+'csv/YOLO/valloss__el1000_opt0.0001__ep100_200.csv').values[:,1]
val_loss5= pd.read_csv(path+'csv/YOLO/valloss__el1000_opt0.00001__ep0_100.csv').values[:,1]
print ('Ошибки на последней эпохе каждого шага:')
print ('100 эпох:', str(round(val_loss1[-1], 4)))
print ('210 эпох:', str(round(val_loss2[-1], 4)))
print ('300 эпох:', str(round(val_loss3[-1], 4)))
print ('400 эпох:', str(round(val_loss4[-1], 4)))
print ('500 эпох:', str(round(val_loss5[-1], 4)))
# Out:
# Ошибки на последней эпохе каждого шага:
# 100 эпох: 10.7404
# 210 эпох: 12.1616
# 300 эпох: 10.5655
# 400 эпох: 6.5367
# 500 эпох: 7.4648

# %% [markdown]
# # Обнаружение объектов
#
# *Разбор данного раздела:* https://youtu.be/5SqeuuO8qRc?t=4351

# %%
model_weight = path + 'weights/YOLOv3__el1000__opt0.00001__ep0_100.h5' # Указываем файл с весами модели
max_boxes = 5 # Максимальное количество ограничивающих рамок на изображении

# %%
model_YOLO = create_YOLOv3(Input(shape=(416, 416, 3)), 9//3) # Создаем модель

# %%
model_YOLO.load_weights(model_weight) # Загружаем посчитанные веса модели
print ('{} загружены.'.format(model_weight))
# Out:
# /content/drive/MyDrive/Baza/Object_detection/Nail/weights/YOLOv3__el1000__opt0.00001__ep0_100.h5 загружены.

# %%
# Создаем набор цветов для ограничивающих рамок
import colorsys 
hsv_tuples = [(x / len(name_classes), 1., 1.) for x in range(len(name_classes))]
colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
colors = list(map(lambda x:(int(x[0]*255), int(x[1]*255), int(x[2]*255)), colors))
np.random.seed(43)
np.random.shuffle(colors)
np.random.seed(None)

# %%
# Берем изображение из набора или с компьютера
#line = annotation['airplane_922'].split()
#image = Image.open(path_main_directory+line[0])
model_image_size = (416,416) # Задаем размер входных данных
image = Image.open(path+'test/755921360180601.jpg') # Загружаем изображение
plt.imshow (image) # Выводим изображение

# %%
def changeShapeImage(image):
    iw, ih = image.size
    w, h = (416, 416)
    scale = min(w / iw, h / ih)
    nw = int(iw * scale)
    nh = int(ih * scale)
    image_for_predict = image.resize((nw, nh), Image.BICUBIC)
    new_image = Image.new('RGB', (416,416), (128, 128, 128))
    new_image.paste(image_for_predict, ((w - nw) // 2, (h - nh) // 2))
    image_for_predict = new_image 
    image_for_predict = np.array(image_for_predict) / 255.
    image_for_predict = image_for_predict.reshape(1, 416, 416, 3)

    return image_for_predict

# %%
def createGrid(level_anchor, predict):
    grid_shape = predict[level_anchor].shape[1:3] # Получим размерность сетки
    grid = [] # Массив для финальной сетки
    grid_row = [] # Массив для столбца
    for i in range(grid_shape[0]): # По всем строкам
      for j in range(grid_shape[1]): # По всем столбцам
        grid_row.append([j , i]) # Создаем элемент [j, i]
      grid.append(grid_row) # Добавляем столбец в финальную сетку
      grid_row = [] # Обнуляем данные для столбца
    grid = np.array(grid) # Переводим в numpy
    grid = np.expand_dims(grid, axis=2) # Добавляем размерность

    return grid, grid_shape

# %%
# Функция расчета сигмоиды для вектора
def sigmoid(x): # На вход подаем массив данных
  return 1/(1+np.exp(-x)) # Возвращаем сигмоиду для всех элементов массива

# %%
def paramBox(feats, grid, grid_shape, anchors_tensor):
    # Получаем параметры бокса

    # Координаты центра bounding box
    xy_param = feats[..., :2] # Выцепляем 0 и 1 параметры из предикта (соответствуют параметрам смещения центра анкора)
    box_xy = (sigmoid(xy_param) + grid)/grid_shape[::-1] # Получаем координаты центра bounding box

    # Высота и ширна bounding box
    wh_param = feats[..., 2:4] # Выцепляем 2 и 3 параметры из предикта (соответствуют праметрам изменения высоты и ширины анкора)
    box_wh = np.exp(wh_param) * anchors_tensor / input_shape[::-1] # Получаем высоту и ширину bounding box

    # Вероятность наличия объекта в анкоре
    conf_param = feats[..., 4:5] # Выцепляем 4 параметр из предикта (соответствуют вероятности обнаружения объекта)
    box_confidence = sigmoid(conf_param) # Получаем вероятность наличия объекта в bounding box

    # Класс объекта
    class_param = feats[...,5:] # Выцепляем 5+ параметры из предикта (соответствуют вероятностям классов объектов)
    box_class_probs = sigmoid(class_param) # Получаем вероятности классов объектов

    return box_xy, box_wh, box_confidence, box_class_probs

# %%
def SideBox(box):
    top, left, bottom, right = box
    top = max(0, np.floor(top + 0.5).astype('int32'))
    left = max(0, np.floor(left + 0.5).astype('int32'))
    bottom = min(image.size[1], np.floor(bottom + 0.5).astype('int32'))
    right = min(image.size[0], np.floor(right + 0.5).astype('int32'))

    return top, left, bottom, right

# %%
def imgPrepare(image, classes_out, name_classes, _boxes_out, _scores_out, font, thickness):
    image_pred = image.copy()
    for i, c in reversed(list(enumerate(classes_out))):
      draw = ImageDraw.Draw(image_pred)
      predicted_class = name_classes[c]
      box = _boxes_out[i]
      score = _scores_out[i]

      label = '{} {:.2f}'.format(predicted_class, score)
      label_size = draw.textsize(label, font)

      top, left, bottom, right = SideBox(box)

      if top - label_size[1] >= 0:
          text_origin = np.array([left, top - label_size[1]])
      else:
          text_origin = np.array([left, top + 1])
      
      for i in range(thickness):
          draw.rectangle(
              [left + i, top + i, right - i, bottom - i],
              outline=colors[c])
      draw.rectangle(
          [tuple(text_origin), tuple(text_origin + label_size)],
          fill=colors[c])
      draw.text(text_origin, label, fill=(0, 0, 0), font=font)
      del draw
    image_pred.save('new_image.jpg')

    return image_pred

# %%
def non_max_suppression_fast(boxes, scores, overlapThresh):	
  if len(boxes) == 0: # Если нет ни одного бокса
    return []

  pick = [] # Индексы возвращаемых боксов
  
  x1 = boxes[:,0] # координаты x левыъ верхних углов
  y1 = boxes[:,1] 
  x2 = boxes[:,2]
  y2 = boxes[:,3]
  
  area = (x2 - x1 + 1) * (y2 - y1 + 1)
  idxs = np.argsort(scores)
  
  while len(idxs) > 0:
    last = len(idxs) - 1
    i = idxs[last]
    pick.append(i)
    
    xx1 = np.maximum(x1[i], x1[idxs[:last]])
    yy1 = np.maximum(y1[i], y1[idxs[:last]])
    xx2 = np.minimum(x2[i], x2[idxs[:last]])
    yy2 = np.minimum(y2[i], y2[idxs[:last]])
    
    w = np.maximum(0, xx2 - xx1 + 1)
    h = np.maximum(0, yy2 - yy1 + 1)
    
    overlap = (w * h) / area[idxs[:last]]
    idxs = np.delete(idxs, np.concatenate(([last],
                                           np.where(overlap > overlapThresh)[0])))
  
  return boxes[pick].astype("int"), scores[pick]

# %%
def createImageBox(image):
    image_for_predict = changeShapeImage(image)

    predict = model_YOLO.predict(image_for_predict)
    num_layers = len(predict) # Получаем количество сеток
    anchor_mask = [[6,7,8], [3,4,5], [0,1,2]] # Задаем маски для 3 уровней анкоров
    input_shape = np.array(predict[0].shape[1:3]) * 32  # Получаем размер выходного изображения
    image_shape = np.array([image.size[1], image.size[0]]) # Сохраняем размер оригинального изображения

    level_anchor = 0 # Укажем уровень сетки
    num_anchors = len(anchors[anchor_mask[level_anchor]]) # Получаем количество анкоров
    anchors_tensor = np.reshape(anchors[anchor_mask[level_anchor]], (1,1,1,num_anchors,2)) # Выбираем анкоры для нашего уровня сетки и решейпим

    grid, grid_shape = createGrid(level_anchor, predict)

    feats = np.reshape(predict[level_anchor], (-1, grid_shape[0], grid_shape[1], num_anchors, num_classes+5))

    box_xy, box_wh, box_confidence, box_class_probs = paramBox(feats, grid, grid_shape, anchors_tensor)

    # Корректируем ограничивающие рамки (Размер изображения на выходе 416х416)
    # И найденные параметры соответствуют именно этой размерности
    # Необходимо найти координаты bounding box для рамерности исходного изображения
    box_yx = box_xy[..., ::-1].copy()
    box_hw = box_wh[..., ::-1].copy()

    new_shape = np.round(image_shape * np.min(input_shape/image_shape)) # Находим размерность пропорциональную исходной с одной из сторон 416
    offset = (input_shape-new_shape)/2./input_shape # Смотрим на сколько надо сместить в относительных координатах
    scale = input_shape/new_shape  # Находим коэфициент масштабирования
    box_yx = (box_yx - offset) * scale # Смещаем по координатам
    box_hw *= scale # Масштабируем ширину и высоту

    box_mins = box_yx - (box_hw / 2.) # Получаем левые верхние координаты (от середины отнимаем половину ширины и высоты)
    box_maxes = box_yx + (box_hw / 2.) # Получаем правые нижнние координаты (к середине прибавляем половину ширины и высоты)
    _boxes =  np.concatenate([
        box_mins[..., 0:1], # yMin
        box_mins[..., 1:2], # xMin
        box_maxes[..., 0:1], # yMax
        box_maxes[..., 1:2]  # xMax
    ], axis=-1)
    _boxes *= np.concatenate([image_shape, image_shape]) # Переводим из относительных координат в абсолютные

    # Получаем выходные параметры
    _boxes_reshape = np.reshape(_boxes, (-1, 4)) # Решейпим все боксы в один массив
    _box_scores = box_confidence * box_class_probs # Получаем вероятность каждого класса (умноженную на веоятность наличия объекта)
    _box_scores_reshape = np.reshape(_box_scores, (-1, num_classes)) # Решейпим в один массив

    mask = _box_scores_reshape >= 0.4 # Берем все объекты, обнаруженные с вероятностью больше 0.7

    _boxes_out = _boxes_reshape[mask[:,0]]
    _scores_out = _box_scores_reshape[:, 0][mask[:,0]] 
    classes_out = np.ones_like(_scores_out,'int32') * 0

    font = ImageFont.truetype(font=path + 'font.otf',
                    size=np.floor(3e-2 * image.size[1] + 0.5).astype('int32'))
    thickness = (image.size[0] + image.size[1]) // 300

    _boxes_out, _scores_out = non_max_suppression_fast(_boxes_out, _scores_out, 0.15)
    classes_out = np.ones_like(_scores_out,'int32') * 0

    image_pred = imgPrepare(image, classes_out, name_classes, _boxes_out, _scores_out, font, thickness)

    return image_pred

# %%
image_pred = createImageBox(image)
plt.imshow(image_pred)

# %%
# files.download('new_image.jpg')
